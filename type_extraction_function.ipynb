# %% [markdown]
# ### Define the Automatic Type Extraction function

# %%
# Copy this code cell to your notebook or python file, no thiry-party library installation required
# Python 3.5+

import re
import unidecode
from collections import Counter 

def deaccent(input_string):
    output_string = unidecode.unidecode(input_string)
    return output_string

def remove_special_characters_and_shrink_whitespace(input_string):
    output_string = re.sub(r'\s+',' ',re.sub(r'[^A-Za-z0-9\s]','',input_string))
    return output_string

def clean_string(input_string):
    output_string = remove_special_characters_and_shrink_whitespace(deaccent(input_string.lower()))
    return output_string

def get_unique_ngram(list_of_ordered_tokens, n):
    # Get the unique ngrams in a string, given a list of ordered tokens in that string
    return set(zip(*[list_of_ordered_tokens[i:i-(n-1)] if i<n-1 else list_of_ordered_tokens[n-1:] for i in range(0,n)]))

def reduce_nested_ngram_freq(x, ngram_freq, mutable_ngram_freq):    
    max_matched_n = 0 # Length of the longest ngram(s) we have matched for this name
    # Note that we have ordered the ngram_freq such that longer ngrams come first, so we can expect to match longest ngram asap
    
    for n, ngram, count in ngram_freq:
        # If the current ngram occurred in more than one name AND the ngram is in the current name
        if count > 1 and ' '+ngram+' ' in ' '+x+' ':
            # If the current ngram is at least the same or even longer than the max n we matched, 
            # just update the max n and move on
            if n >= max_matched_n:
                max_matched_n = n                
            else:
            # Else if the current ngram is shorter than longest ngram we have matched in this name,
            # this probably suggests the current ngram is part of the longest ngram we matched before,
            # thus we need to decrease the frequency count for this shorter ngram as it is not an independent count
                mutable_ngram_freq[ngram] -= 1
                
def extract_types(input_list, thres = None, maximum_expected_number_of_types = 20, return_proportion = False):
    
    name_list = [clean_string(name) for name in list(input_list)]
    number_of_names_in_this_list = len(name_list)

    phrase_counter = Counter()
    # For each name in the name list, tokenize it and count the ngrams in the name, 
    # and add the frequency of ngrams to the phrase counter
    for name in name_list:
        tokens_in_name = name.strip().split(" ")
        for n in range(1,min(len(tokens_in_name),10)+1): # Record frequency of ngrams up to 10 tokens' long
            phrase_counter.update( get_unique_ngram(tokens_in_name, n) )
    
    # For each pair of (token_sequence, count) in the phrase_counter, convert it to (n, ngram, count), where n is the "n" in ngram
    ngram_freq = [(len(token_sequence),' '.join(token_sequence), count) for token_sequence, count in phrase_counter.most_common() if count >= round(len(name_list)*0.001)]
    
    # Sort the ngram_freq list in the reverse order of n, such that longer ngrams is earlier in the list
    ngram_freq = sorted(ngram_freq, key = lambda entry: -entry[0])
  
    # Create a mutable copy of the ngram_freq list
    mutable_ngram_freq = {ngram : count for n, ngram, count in ngram_freq}

    # Iterate through all the names in the name list, use the reduce the frequency count for the ngrams that are part of longer ngram
    for name in name_list:
        reduce_nested_ngram_freq(name, ngram_freq, mutable_ngram_freq)
    
    sorted_consolidated_ngram_freq = sorted(list(mutable_ngram_freq.items()), key = lambda t: -t[-1])

    # If thres is not provided, return the top k types found, with k defined by maximum_expected_number_of_types
    if thres is None:
        if len(sorted_consolidated_ngram_freq)>maximum_expected_number_of_types:
            minimum_count = sorted_consolidated_ngram_freq[maximum_expected_number_of_types+1][-1]
        else:
            minimum_count = 1            
    # If thres is provided, calculate the minimum count by multiplying threshold with number of names in the list
    else:
        minimum_count = max(1, int(thres*number_of_names_in_this_list))    
    sorted_consolidated_ngram_freq = [item for item in sorted_consolidated_ngram_freq if item[-1]>minimum_count]
    
    # If return_proportion is true, return the results in the format (ngram, proportion, count)
    if return_proportion:
        sorted_consolidated_ngram_freq = [(item, round(count/number_of_names_in_this_list,3), count) for item, count in sorted_consolidated_ngram_freq]
    
    return sorted_consolidated_ngram_freq

# %% [markdown]
# ### Extract Common Phrases from Nature Dataset

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# Read in the dataset
df = pd.read_csv('sub-saharan_health_facilities.csv')
# Change column names to be more readable
df = df.rename(columns = {'Facility n':'name','Facility t':'given_type'})
# Drop entries whose name field is missing or empty
df['orig_name'] = df['name'].copy()
df['name'] = df['name'].apply(lambda x: np.nan if x.strip() == '' else x)
df = df.dropna(subset=['name']).copy()
df['name'] = df['name'].apply(clean_string)
df['given_type'] = df['given_type'].apply(clean_string)
# Inspect the first 5 rows
df.head()
# Out:
#   Country Admin1                               name          given_type  \
# 0  Angola  Bengo            hospital barra do dande            hospital
# 1  Angola  Bengo                hospital dos dembos            hospital
# 2  Angola  Bengo       hospital municipal de ambriz  municipal hospital
# 3  Angola  Bengo  hospital municipal de bula atumba  municipal hospital
# 4  Angola  Bengo        hospital municipal de dande  municipal hospital
#
#   Ownership     Lat     Long     LL source         coordinates  \
# 0     Govt. -8.6560  13.4919  Google Earth   [-8.656, 13.4919]
# 1     Govt. -8.5026  14.5862  Google Earth  [-8.5026, 14.5862]
# 2     Govt. -7.8522  13.1307  Google Earth  [-7.8522, 13.1307]
# 3     Govt. -8.6742  14.7925  Google Earth  [-8.6742, 14.7925]
# 4     Govt. -8.5835  13.6569  Google Earth  [-8.5835, 13.6569]
#
#                            orig_name
# 0            Hospital Barra Do Dande
# 1                Hospital Dos Dembos
# 2       Hospital Municipal de Ambriz
# 3  Hospital Municipal de Bula Atumba
# 4        Hospital Municipal de Dande

# %% [markdown]
# ### Demonstrate the Results from Common Bottom-up Approach

# %%
name_list = df.sample(frac=0.1,random_state=0).loc[:, 'name'].tolist()
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer(ngram_range=(1, 5))
ngram_sparse_matrix = count_vectorizer.fit_transform(name_list)
vocabulary = count_vectorizer.vocabulary_
ngram_counts = ngram_sparse_matrix.toarray().sum(axis=0)
ngram_freq_with_sklearn = sorted([(k,round(ngram_counts[i]/(len(df)*0.1),3),ngram_counts[i]) for k,i in vocabulary.items()], key = lambda x: -x[-1])
print(tabulate(ngram_freq_with_sklearn[:18], headers=['Type', 'Proportion', 'Count'], tablefmt='fancy_grid'))
# Out:
# ╒═══════════════════════╤══════════════╤═════════╕
# │ Type                  │   Proportion │   Count │
# ╞═══════════════════════╪══════════════╪═════════╡
# │ centre                │        0.429 │    4235 │
# ├───────────────────────┼──────────────┼─────────┤
# │ health                │        0.412 │    4065 │
# ├───────────────────────┼──────────────┼─────────┤
# │ de                    │        0.306 │    3024 │
# ├───────────────────────┼──────────────┼─────────┤
# │ sante                 │        0.253 │    2494 │
# ├───────────────────────┼──────────────┼─────────┤
# │ de sante              │        0.252 │    2490 │
# ├───────────────────────┼──────────────┼─────────┤
# │ health centre         │        0.224 │    2213 │
# ├───────────────────────┼──────────────┼─────────┤
# │ centre de             │        0.181 │    1792 │
# ├───────────────────────┼──────────────┼─────────┤
# │ centre de sante       │        0.181 │    1790 │
# ├───────────────────────┼──────────────┼─────────┤
# │ clinic                │        0.14  │    1378 │
# ├───────────────────────┼──────────────┼─────────┤
# │ dispensary            │        0.132 │    1302 │
# ├───────────────────────┼──────────────┼─────────┤
# │ post                  │        0.094 │     926 │
# ├───────────────────────┼──────────────┼─────────┤
# │ health post           │        0.094 │     925 │
# ├───────────────────────┼──────────────┼─────────┤
# │ primary               │        0.075 │     740 │
# ├───────────────────────┼──────────────┼─────────┤
# │ primary health        │        0.075 │     740 │
# ├───────────────────────┼──────────────┼─────────┤
# │ poste                 │        0.069 │     677 │
# ├───────────────────────┼──────────────┼─────────┤
# │ poste de              │        0.068 │     674 │
# ├───────────────────────┼──────────────┼─────────┤
# │ poste de sante        │        0.068 │     674 │
# ├───────────────────────┼──────────────┼─────────┤
# │ primary health centre │        0.05  │     490 │
# ╘═══════════════════════╧══════════════╧═════════╛

# %% [markdown]
# ### Run the proposed function on the Nature Dataset

# %%
# Get the unique countries in the dataset
list_of_countries = df['Country'].unique().tolist()

# Build a dictionary where entry key is the name of the country, 
# entry value is the list of health facility types in that country
country_and_common_facility_types = {}

# Iterate through all the unique countries
for country_name in list_of_countries:
    
    print('Country: ',country_name,'\n')

    # Get the part of the data that belongs to this country 
    country_part = df.loc[df['Country']== country_name, 'name'].tolist()
    
    common_facility_types_in_this_country = extract_types(country_part, return_proportion = True)
    
    country_and_common_facility_types[country_name] = common_facility_types_in_this_country
    
    print(tabulate(common_facility_types_in_this_country, headers=['Type', 'Proportion', 'Count'], tablefmt='fancy_grid'))
    
    print('\n-------------------------------------------------------------------------------------\n')
# Out:
# Country:  Angola
#
# ╒═════════════════════════════╤══════════════╤═════════╕
# │ Type                        │   Proportion │   Count │
# ╞═════════════════════════════╪══════════════╪═════════╡
# │ health post                 │        0.59  │     929 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ health centre               │        0.121 │     191 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ municipal hospital          │        0.047 │      74 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ centro materno infantil     │        0.026 │      41 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hospital                    │        0.018 │      28 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hospital municipal de       │        0.014 │      22 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ sede health centre          │        0.008 │      12 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ 1 health post               │        0.004 │       7 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ municipal health centre     │        0.004 │       6 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ missao catolica health post │        0.003 │       5 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ aldeamento no health post   │        0.003 │       5 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ ii health post              │        0.003 │       5 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ sede i health post          │        0.003 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ i health post               │        0.003 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hospital provincial de      │        0.003 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ provincial hospital         │        0.003 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ sector do                   │        0.003 │       4 │
# ╘═════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Benin
#
# ╒═══════════════════════════════════╤══════════════╤═════════╕
# │ Type                              │   Proportion │   Count │
# ╞═══════════════════════════════════╪══════════════╪═════════╡
# │ centre de sante darrondissement   │        0.366 │     300 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante                   │        0.295 │     242 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre communal de sante          │        0.161 │     132 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ dispensaire                       │        0.031 │      25 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre medical                    │        0.027 │      22 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ hopital de zone                   │        0.026 │      21 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ hopital                           │        0.022 │      18 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ uvs unites de sante de village    │        0.011 │       9 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante central           │        0.011 │       9 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante de sousprefecture │        0.01  │       8 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre hospitalier departemental  │        0.006 │       5 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ clinique clinique                 │        0.004 │       3 │
# ├───────────────────────────────────┼──────────────┼─────────┤
# │ centre medicosocial               │        0.004 │       3 │
# ╘═══════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Botswana
#
# ╒════════════════════════════╤══════════════╤═════════╕
# │ Type                       │   Proportion │   Count │
# ╞════════════════════════════╪══════════════╪═════════╡
# │ health post                │        0.513 │     320 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ clinic                     │        0.357 │     223 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ primary hospital           │        0.027 │      17 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ district hospital          │        0.011 │       7 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ memorial district hospital │        0.005 │       3 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ kubung health post         │        0.005 │       3 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ boseja clinic              │        0.005 │       3 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ 11 clinic                  │        0.005 │       3 │
# ├────────────────────────────┼──────────────┼─────────┤
# │ new                        │        0.005 │       3 │
# ╘════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Burkina Faso
#
# ╒════════════════════════════════════════════════════╤══════════════╤═════════╕
# │ Type                                               │   Proportion │   Count │
# ╞════════════════════════════════════════════════════╪══════════════╪═════════╡
# │ centre de sante et de promotion sociale            │        0.787 │    1355 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ dispensaire                                        │        0.043 │      74 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre medical avec antenne chirurgicale           │        0.028 │      49 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre medical                                     │        0.022 │      38 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ urbain centre de sante et de promotion sociale     │        0.006 │      10 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre hospitalier regional                        │        0.005 │       9 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante et de promotion sociale         │        0.004 │       7 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ i centre de sante et de promotion sociale          │        0.003 │       6 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ secteur 5 centre de sante et de promotion sociale  │        0.003 │       5 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ tangaye centre de sante et de promotion sociale    │        0.003 │       5 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ ziga centre de sante et de promotion sociale       │        0.002 │       4 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ de                                                 │        0.002 │       4 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ secteur 10 centre de sante et de promotion sociale │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ koro centre de sante et de promotion sociale       │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ tanghin centre de sante et de promotion sociale    │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ yalgo centre de sante et de promotion sociale      │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ 9 centre de sante et de promotion sociale          │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ botou centre de sante et de promotion sociale      │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ doure centre de sante et de promotion sociale      │        0.002 │       3 │
# ├────────────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre hospitalier universitaire national          │        0.002 │       3 │
# ╘════════════════════════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Burundi
# ╒═══════════════════════════╤══════════════╤═════════╕
# │ Type                      │   Proportion │   Count │
# ╞═══════════════════════════╪══════════════╪═════════╡
# │ centre de sante           │        0.705 │     469 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ hopital de district       │        0.069 │      46 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ i centre de sante         │        0.015 │      10 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante        │        0.011 │       7 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ mubuga centre de sante    │        0.006 │       4 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ nyarunazi centre de sante │        0.006 │       4 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ kivoga centre de sante    │        0.006 │       4 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ rugazi centre de sante    │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ kinama centre de sante    │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ muyange centre de sante   │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ nyagatovu centre de sante │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ kibimba centre de sante   │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ murore centre de sante    │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ buhoro centre de sante    │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ kabanga centre de sante   │        0.005 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ hopital tertiaire         │        0.005 │       3 │
# ╘═══════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Cameroon
#
# ╒════════════════════════════════════╤══════════════╤═════════╕
# │ Type                               │   Proportion │   Count │
# ╞════════════════════════════════════╪══════════════╪═════════╡
# │ centre de sante integre            │        0.658 │    2014 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ centre medical darrondissement     │        0.07  │     215 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante                    │        0.054 │     166 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ hopital de district                │        0.053 │     162 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ catholique centre de sante         │        0.023 │      71 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ 2 centre de sante integre          │        0.011 │      35 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ 1 centre de sante integre          │        0.01  │      31 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ catholique dispensaire             │        0.007 │      21 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ eec centre de sante                │        0.006 │      19 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante integre         │        0.006 │      18 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ catholique centre de sante integre │        0.005 │      14 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ hopital regional                   │        0.005 │      14 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ dispensaire                        │        0.005 │      14 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ ad lucem centre de sante           │        0.004 │      12 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ epc centre de sante                │        0.004 │      12 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ urbain centre de sante integre     │        0.004 │      11 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ i centre de sante integre          │        0.004 │      11 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ baptist centre de sante integre    │        0.003 │      10 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ urban centre de sante integre      │        0.003 │       9 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ baptist centre de sante            │        0.003 │       9 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ protestant centre de sante         │        0.003 │       9 │
# ╘════════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Cape Verde
#
# ╒═════════════════════════╤══════════════╤═════════╕
# │ Type                    │   Proportion │   Count │
# ╞═════════════════════════╪══════════════╪═════════╡
# │ centro de saude         │        0.47  │      31 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ postos sanitarios       │        0.333 │      22 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ hospitais regionais     │        0.106 │       7 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ vaz postos sanitarios   │        0.03  │       2 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ pedro postos sanitarios │        0.03  │       2 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ hospitais centrais      │        0.03  │       2 │
# ╘═════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Central African Republic
#
# ╒════════════════════════════════╤══════════════╤═════════╕
# │ Type                           │   Proportion │   Count │
# ╞════════════════════════════════╪══════════════╪═════════╡
# │ poste de sante                 │        0.56  │     311 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante c              │        0.103 │      57 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante e              │        0.099 │      55 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante b              │        0.076 │      42 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante a              │        0.074 │      41 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ hopital prefectoraux           │        0.022 │      12 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ hopital regional universitaire │        0.009 │       5 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ disp poste de sante            │        0.007 │       4 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ i poste de sante               │        0.007 │       4 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ ii poste de sante              │        0.005 │       3 │
# ├────────────────────────────────┼──────────────┼─────────┤
# │ hopital centraux               │        0.005 │       3 │
# ╘════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Chad
#
# ╒════════════════════════╤══════════════╤═════════╕
# │ Type                   │   Proportion │   Count │
# ╞════════════════════════╪══════════════╪═════════╡
# │ centre de sante        │        0.804 │    1031 │
# ├────────────────────────┼──────────────┼─────────┤
# │ hopital de district    │        0.055 │      70 │
# ├────────────────────────┼──────────────┼─────────┤
# │ urbain centre de sante │        0.018 │      23 │
# ├────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante     │        0.01  │      13 │
# ├────────────────────────┼──────────────┼─────────┤
# │ est centre de sante    │        0.008 │      10 │
# ├────────────────────────┼──────────────┼─────────┤
# │ nord centre de sante   │        0.007 │       9 │
# ├────────────────────────┼──────────────┼─────────┤
# │ ouest centre de sante  │        0.005 │       7 │
# ├────────────────────────┼──────────────┼─────────┤
# │ centre centre de sante │        0.005 │       6 │
# ├────────────────────────┼──────────────┼─────────┤
# │ hopital de regional    │        0.005 │       6 │
# ├────────────────────────┼──────────────┼─────────┤
# │ sud centre de sante    │        0.004 │       5 │
# ├────────────────────────┼──────────────┼─────────┤
# │ public centre de sante │        0.003 │       4 │
# ├────────────────────────┼──────────────┼─────────┤
# │ i centre de sante      │        0.003 │       4 │
# ├────────────────────────┼──────────────┼─────────┤
# │ ngolo centre de sante  │        0.002 │       3 │
# ├────────────────────────┼──────────────┼─────────┤
# │ 1 centre de sante      │        0.002 │       3 │
# ├────────────────────────┼──────────────┼─────────┤
# │ pub centre de sante    │        0.002 │       3 │
# ╘════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Comoros
#
# ╒═════════════════════════════╤══════════════╤═════════╕
# │ Type                        │   Proportion │   Count │
# ╞═════════════════════════════╪══════════════╪═════════╡
# │ postes de sante             │        0.682 │      45 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ centre de sante             │        0.182 │      12 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ centre medicourbain         │        0.045 │       3 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ centre hospitalier regional │        0.03  │       2 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ centre medicochirurgical    │        0.03  │       2 │
# ╘═════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Congo
#
# ╒═══════════════════════════════╤══════════════╤═════════╕
# │ Type                          │   Proportion │   Count │
# ╞═══════════════════════════════╪══════════════╪═════════╡
# │ centre de sante integre       │        0.747 │     245 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ lhopital de base              │        0.03  │      10 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante integre    │        0.027 │       9 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ hopital comboutique           │        0.027 │       9 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ centr centre de sante integre │        0.018 │       6 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ hopital general               │        0.012 │       4 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ kayes centre de sante integre │        0.009 │       3 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ gare centre de sante integre  │        0.009 │       3 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ i centre de sante integre     │        0.009 │       3 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ st centre de sante integre    │        0.009 │       3 │
# ╘═══════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Cote d'Ivoire
# ╒═══════════════════════════════════════╤══════════════╤═════════╕
# │ Type                                  │   Proportion │   Count │
# ╞═══════════════════════════════════════╪══════════════╪═════════╡
# │ centre de sante rural                 │        0.694 │    1244 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ centre de sante urbain                │        0.15  │     269 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ hopital general                       │        0.039 │      70 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ hospitalier regional                  │        0.011 │      19 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ centre medicosocial                   │        0.009 │      17 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ 2 centre de sante rural               │        0.006 │      11 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ 1 centre de sante rural               │        0.004 │       7 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ de sanpedro centre de sante urbain    │        0.003 │       5 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante rural              │        0.003 │       5 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ i centre de sante rural               │        0.003 │       5 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ hospitalier universitaire             │        0.002 │       4 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ de treichville centre de sante urbain │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ de yopougon centre de sante urbain    │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ de abengourou centre de sante urbain  │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ de tiassale centre de sante rural     │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ divo centre de sante urbain           │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ village centre de sante rural         │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ kouassikro centre de sante rural      │        0.002 │       3 │
# ├───────────────────────────────────────┼──────────────┼─────────┤
# │ daloa centre de sante urbain          │        0.002 │       3 │
# ╘═══════════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Democratic Republic of the Congo
#
# ╒══════════════════════════════╤══════════════╤═════════╕
# │ Type                         │   Proportion │   Count │
# ╞══════════════════════════════╪══════════════╪═════════╡
# │ centre de sante              │        0.54  │    7877 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ poste de sante               │        0.266 │    3879 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ centre medical               │        0.055 │     805 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ centre de sante de reference │        0.031 │     454 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ hopital general de reference │        0.023 │     340 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ clinique                     │        0.012 │     168 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ dispensaire                  │        0.009 │     127 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ polyclinique                 │        0.007 │      97 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ 2 centre de sante            │        0.005 │      67 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ 1 centre de sante            │        0.004 │      52 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ general referencia           │        0.003 │      44 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ ii centre de sante           │        0.003 │      43 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ centre hopital               │        0.003 │      41 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ 2 poste de sante             │        0.003 │      39 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ ii poste de sante            │        0.003 │      39 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ etat centre de sante         │        0.002 │      26 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ la                           │        0.002 │      26 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ i centre de sante            │        0.002 │      23 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ i poste de sante             │        0.002 │      23 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ 1 poste de sante             │        0.001 │      21 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ bolingo centre de sante      │        0.001 │      20 │
# ╘══════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Djibouti
#
# ╒═════════════════════════╤══════════════╤═════════╕
# │ Type                    │   Proportion │   Count │
# ╞═════════════════════════╪══════════════╪═════════╡
# │ health post             │        0.621 │      41 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ community health centre │        0.182 │      12 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ hospital                │        0.136 │       9 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ hospital medical centre │        0.045 │       3 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ al                      │        0.03  │       2 │
# ╘═════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Equatorial Guinea
#
# ╒══════════════════════════╤══════════════╤═════════╕
# │ Type                     │   Proportion │   Count │
# ╞══════════════════════════╪══════════════╪═════════╡
# │ district hospital        │        0.234 │      11 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ kientem                  │        0.17  │       8 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ litoral                  │        0.128 │       6 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ welenzas                 │        0.128 │       6 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ bioko norte              │        0.085 │       4 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ centro sur               │        0.085 │       4 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ provincial hospital      │        0.085 │       4 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ 1                        │        0.064 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ 2                        │        0.064 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ 3                        │        0.064 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ 4                        │        0.064 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ 5                        │        0.064 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ 6                        │        0.064 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ public regional hospital │        0.043 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ sur 1                    │        0.043 │       2 │
# ╘══════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Eritrea
#
# ╒══════════════════════════╤══════════════╤═════════╕
# │ Type                     │   Proportion │   Count │
# ╞══════════════════════════╪══════════════╪═════════╡
# │ health station           │        0.658 │     177 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ health centre            │        0.193 │      52 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ hospital                 │        0.052 │      14 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ mini hospital            │        0.019 │       5 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ clinic                   │        0.015 │       4 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ alebu health station     │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ adi health station       │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ dekemhare health station │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ saba health station      │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ mai dma health           │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ kerkebet health          │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ adi qeyh                 │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ forto health             │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ mini clinic              │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ tsorona health           │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ referral hospital        │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ health clinic            │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ godaif health            │        0.007 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ ghinda health            │        0.007 │       2 │
# ╘══════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  eSwatini
#
# ╒═══════════════════════╤══════════════╤═════════╕
# │ Type                  │   Proportion │   Count │
# ╞═══════════════════════╪══════════════╪═════════╡
# │ clinic                │        0.644 │      87 │
# ├───────────────────────┼──────────────┼─────────┤
# │ nazarene clinic       │        0.111 │      15 │
# ├───────────────────────┼──────────────┼─────────┤
# │ public health unit    │        0.059 │       8 │
# ├───────────────────────┼──────────────┼─────────┤
# │ health centre         │        0.059 │       8 │
# ├───────────────────────┼──────────────┼─────────┤
# │ st                    │        0.044 │       6 │
# ├───────────────────────┼──────────────┼─────────┤
# │ community clinic      │        0.022 │       3 │
# ├───────────────────────┼──────────────┼─────────┤
# │ hospital              │        0.022 │       3 │
# ├───────────────────────┼──────────────┼─────────┤
# │ salvation army clinic │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ piggs peak            │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ giving life           │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ government hospital   │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ mission clinic        │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ nazerene clinic       │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ ekuphileni            │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ new                   │        0.015 │       2 │
# ├───────────────────────┼──────────────┼─────────┤
# │ zombodze              │        0.015 │       2 │
# ╘═══════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Ethiopia
# ╒═════════════════════════╤══════════════╤═════════╕
# │ Type                    │   Proportion │   Count │
# ╞═════════════════════════╪══════════════╪═════════╡
# │ clinic                  │        0.483 │    2520 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ health post             │        0.176 │     917 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ health centre           │        0.138 │     720 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ health station          │        0.026 │     138 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ hospital                │        0.024 │     125 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ arada clinic            │        0.009 │      49 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ bole clinic             │        0.008 │      44 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ kolfe keraniyo clinic   │        0.008 │      43 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ nefas silk lafto clinic │        0.007 │      38 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ yeka clinic             │        0.007 │      38 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ kirkos clinic           │        0.006 │      33 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ clinic 1                │        0.006 │      29 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ clinic 2                │        0.006 │      29 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ addis ketema clinic     │        0.005 │      27 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ lideta clinic           │        0.005 │      27 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ akaki kaliti clinic     │        0.004 │      23 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ gulele clinic           │        0.004 │      23 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ clinic 3                │        0.004 │      20 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ clinic 4                │        0.003 │      17 │
# ├─────────────────────────┼──────────────┼─────────┤
# │ tsegede health post     │        0.003 │      16 │
# ╘═════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Gabon
#
# ╒════════════════════════╤══════════════╤═════════╕
# │ Type                   │   Proportion │   Count │
# ╞════════════════════════╪══════════════╪═════════╡
# │ dispensaire            │        0.614 │     333 │
# ├────────────────────────┼──────────────┼─────────┤
# │ centre de sante        │        0.17  │      92 │
# ├────────────────────────┼──────────────┼─────────┤
# │ centre medical         │        0.074 │      40 │
# ├────────────────────────┼──────────────┼─────────┤
# │ 1 dispensaire          │        0.02  │      11 │
# ├────────────────────────┼──────────────┼─────────┤
# │ hospitalier regional   │        0.017 │       9 │
# ├────────────────────────┼──────────────┼─────────┤
# │ 2 dispensaire          │        0.015 │       8 │
# ├────────────────────────┼──────────────┼─────────┤
# │ 12 dispensaire         │        0.009 │       5 │
# ├────────────────────────┼──────────────┼─────────┤
# │ ii dispensaire         │        0.007 │       4 │
# ├────────────────────────┼──────────────┼─────────┤
# │ centre de sante urbain │        0.006 │       3 │
# ╘════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Gambia
#
# ╒═══════════════════════════════╤══════════════╤═════════╕
# │ Type                          │   Proportion │   Count │
# ╞═══════════════════════════════╪══════════════╪═════════╡
# │ clinic                        │        0.408 │      42 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ minor health centre           │        0.359 │      37 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ major health centre           │        0.068 │       7 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ hospital                      │        0.039 │       4 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ kunda minor health centre     │        0.029 │       3 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ rch minor health centre       │        0.019 │       2 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ karantaba minor health centre │        0.019 │       2 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ gfpa clinic                   │        0.019 │       2 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ jeswang clinic                │        0.019 │       2 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ general hospital              │        0.019 │       2 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ kunda                         │        0.019 │       2 │
# ├───────────────────────────────┼──────────────┼─────────┤
# │ for                           │        0.019 │       2 │
# ╘═══════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Ghana
#
# ╒═════════════════════════════════════════════╤══════════════╤═════════╕
# │ Type                                        │   Proportion │   Count │
# ╞═════════════════════════════════════════════╪══════════════╪═════════╡
# │ health centre                               │        0.334 │     654 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ communitybased health planning and services │        0.31  │     608 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ clinic                                      │        0.074 │     145 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ community clinic                            │        0.034 │      66 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ rural clinic                                │        0.031 │      60 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ district hospital                           │        0.027 │      52 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ hospital                                    │        0.018 │      36 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ government district hospital                │        0.012 │      23 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ methodist clinic                            │        0.007 │      13 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ polyclinic                                  │        0.007 │      13 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ st                                          │        0.006 │      12 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ sda clinic                                  │        0.006 │      11 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ regional hospital                           │        0.004 │       8 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ government hospital                         │        0.004 │       8 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ presby clinic                               │        0.004 │       7 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ salvation army clinic                       │        0.003 │       6 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ health clinic                               │        0.003 │       6 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ sda hospital                                │        0.003 │       6 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ chps clinic                                 │        0.003 │       6 │
# ╘═════════════════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Guinea
# ╒═════════════════════════════╤══════════════╤═════════╕
# │ Type                        │   Proportion │   Count │
# ╞═════════════════════════════╪══════════════╪═════════╡
# │ poste de sante              │        0.604 │    1055 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ centre de sante             │        0.228 │     398 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hopital prefectoral         │        0.014 │      25 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hopital regional            │        0.004 │       7 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ dar es salam poste de sante │        0.003 │       6 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ balandougou poste de sante  │        0.003 │       5 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hamdallaye poste de sante   │        0.003 │       5 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ missira poste de sante      │        0.002 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ hafia poste de sante        │        0.002 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ madina centre de sante      │        0.002 │       4 │
# ├─────────────────────────────┼──────────────┼─────────┤
# │ dara poste de sante         │        0.002 │       4 │
# ╘═════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Guinea Bissau
#
# ╒══════════════════════╤══════════════╤═════════╕
# │ Type                 │   Proportion │   Count │
# ╞══════════════════════╪══════════════╪═════════╡
# │ hospital regional de │        0.375 │       3 │
# ├──────────────────────┼──────────────┼─────────┤
# │ hospital             │        0.375 │       3 │
# ├──────────────────────┼──────────────┼─────────┤
# │ hospital de          │        0.25  │       2 │
# ├──────────────────────┼──────────────┼─────────┤
# │ de                   │        0.25  │       2 │
# ╘══════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Kenya
#
# ╒═══════════════════════╤══════════════╤═════════╕
# │ Type                  │   Proportion │   Count │
# ╞═══════════════════════╪══════════════╪═════════╡
# │ dispensary            │        0.637 │    3915 │
# ├───────────────────────┼──────────────┼─────────┤
# │ health centre         │        0.154 │     947 │
# ├───────────────────────┼──────────────┼─────────┤
# │ clinic                │        0.027 │     167 │
# ├───────────────────────┼──────────────┼─────────┤
# │ district hospital     │        0.019 │     118 │
# ├───────────────────────┼──────────────┼─────────┤
# │ subdistrict hospital  │        0.017 │     105 │
# ├───────────────────────┼──────────────┼─────────┤
# │ catholic dispensary   │        0.016 │     100 │
# ├───────────────────────┼──────────────┼─────────┤
# │ hospital              │        0.013 │      82 │
# ├───────────────────────┼──────────────┼─────────┤
# │ st                    │        0.011 │      66 │
# ├───────────────────────┼──────────────┼─────────┤
# │ ack dispensary        │        0.008 │      52 │
# ├───────────────────────┼──────────────┼─────────┤
# │ community dispensary  │        0.007 │      46 │
# ├───────────────────────┼──────────────┼─────────┤
# │ aic dispensary        │        0.007 │      40 │
# ├───────────────────────┼──────────────┼─────────┤
# │ mission dispensary    │        0.006 │      37 │
# ├───────────────────────┼──────────────┼─────────┤
# │ mission hospital      │        0.006 │      36 │
# ├───────────────────────┼──────────────┼─────────┤
# │ medical centre        │        0.005 │      33 │
# ├───────────────────────┼──────────────┼─────────┤
# │ pcea dispensary       │        0.005 │      32 │
# ├───────────────────────┼──────────────┼─────────┤
# │ cdf dispensary        │        0.005 │      28 │
# ├───────────────────────┼──────────────┼─────────┤
# │ sub district hospital │        0.004 │      27 │
# ├───────────────────────┼──────────────┼─────────┤
# │ medical clinic        │        0.004 │      26 │
# ├───────────────────────┼──────────────┼─────────┤
# │ model health centre   │        0.004 │      25 │
# ├───────────────────────┼──────────────┼─────────┤
# │ mission health centre │        0.004 │      23 │
# ├───────────────────────┼──────────────┼─────────┤
# │ sda dispensary        │        0.004 │      22 │
# ╘═══════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Lesotho
#
# ╒══════════════════════════╤══════════════╤═════════╕
# │ Type                     │   Proportion │   Count │
# ╞══════════════════════════╪══════════════╪═════════╡
# │ health centre            │        0.769 │      90 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ hospital                 │        0.154 │      18 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ st theresa health centre │        0.026 │       3 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ sda health centre        │        0.017 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ filter clinic            │        0.017 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ st josephs               │        0.017 │       2 │
# ├──────────────────────────┼──────────────┼─────────┤
# │ st james                 │        0.017 │       2 │
# ╘══════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Liberia
#
# ╒════════════════╤══════════════╤═════════╕
# │ Type           │   Proportion │   Count │
# ╞════════════════╪══════════════╪═════════╡
# │ town           │        0.112 │      83 │
# ├────────────────┼──────────────┼─────────┤
# │ community      │        0.023 │      17 │
# ├────────────────┼──────────────┼─────────┤
# │ clinic         │        0.012 │       9 │
# ├────────────────┼──────────────┼─────────┤
# │ mission        │        0.012 │       9 │
# ├────────────────┼──────────────┼─────────┤
# │ hospital       │        0.011 │       8 │
# ├────────────────┼──────────────┼─────────┤
# │ st             │        0.009 │       7 │
# ├────────────────┼──────────────┼─────────┤
# │ village        │        0.009 │       7 │
# ├────────────────┼──────────────┼─────────┤
# ...
# │ chc               │        0.065 │     279 │
# ├───────────────────┼──────────────┼─────────┤
# │ satellite clinic  │        0.046 │     200 │
# ├───────────────────┼──────────────┼─────────┤
# │ gateway clinic    │        0.029 │     125 │
# ├───────────────────┼──────────────┼─────────┤
# │ park clinic       │        0.008 │      35 │
# ├───────────────────┼──────────────┼─────────┤
# │ street clinic     │        0.008 │      34 │
# ├───────────────────┼──────────────┼─────────┤
# │ health post       │        0.008 │      33 │
# ├───────────────────┼──────────────┼─────────┤
# │ st                │        0.005 │      22 │
# ├───────────────────┼──────────────┼─────────┤
# │ 2 clinic          │        0.005 │      20 │
# ├───────────────────┼──────────────┼─────────┤
# │ 1 clinic          │        0.004 │      16 │
# ├───────────────────┼──────────────┼─────────┤
# │ town clinic       │        0.003 │      15 │
# ├───────────────────┼──────────────┼─────────┤
# │ la clinic         │        0.003 │      14 │
# ├───────────────────┼──────────────┼─────────┤
# │ dr                │        0.003 │      13 │
# ├───────────────────┼──────────────┼─────────┤
# │ memorial hospital │        0.003 │      12 │
# ├───────────────────┼──────────────┼─────────┤
# │ de                │        0.003 │      12 │
# ├───────────────────┼──────────────┼─────────┤
# │ road clinic       │        0.003 │      11 │
# ├───────────────────┼──────────────┼─────────┤
# │ umlazi            │        0.003 │      11 │
# ╘═══════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  South Sudan
#
# ╒═════════════════════════════════╤══════════════╤═════════╕
# │ Type                            │   Proportion │   Count │
# ╞═════════════════════════════════╪══════════════╪═════════╡
# │ primary health care unit        │        0.695 │    1215 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ primary health care centre      │        0.168 │     294 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ county hospital                 │        0.016 │      28 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ state hospital                  │        0.005 │       9 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ 2 primary health care unit      │        0.003 │       6 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ 1 primary health care unit      │        0.003 │       5 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ 1 primary health care centre    │        0.002 │       4 │
# ├─────────────────────────────────┼──────────────┼─────────┤
# │ clinic primary health care unit │        0.002 │       4 │
# ╘═════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Sudan
#
# ╒═══════════════════╤══════════════╤═════════╕
# │ Type              │   Proportion │   Count │
# ╞═══════════════════╪══════════════╪═════════╡
# │ hospital          │        0.882 │     240 │
# ├───────────────────┼──────────────┼─────────┤
# │ al                │        0.165 │      45 │
# ├───────────────────┼──────────────┼─────────┤
# │ wadi              │        0.04  │      11 │
# ├───────────────────┼──────────────┼─────────┤
# │ rural hospital    │        0.037 │      10 │
# ├───────────────────┼──────────────┼─────────┤
# │ ad                │        0.029 │       8 │
# ├───────────────────┼──────────────┼─────────┤
# │ abu               │        0.022 │       6 │
# ├───────────────────┼──────────────┼─────────┤
# │ um                │        0.022 │       6 │
# ├───────────────────┼──────────────┼─────────┤
# │ el                │        0.018 │       5 │
# ├───────────────────┼──────────────┼─────────┤
# │ teaching hospital │        0.015 │       4 │
# ╘═══════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Tanzania
#
# ╒══════════════════════════════╤══════════════╤═════════╕
# │ Type                         │   Proportion │   Count │
# ╞══════════════════════════════╪══════════════╪═════════╡
# │ dispensary                   │        0.815 │    5138 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ health centre                │        0.106 │     669 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ hospital                     │        0.013 │      81 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ district hospital            │        0.01  │      63 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ rc dispensary                │        0.008 │      50 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ st                           │        0.006 │      38 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ mission dispensary           │        0.006 │      37 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ designated district hospital │        0.006 │      36 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ regional referral hospital   │        0.004 │      26 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ arafa                        │        0.004 │      24 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ sda dispensary               │        0.004 │      23 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ b dispensary                 │        0.003 │      19 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ mico                         │        0.003 │      16 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ juu dispensary               │        0.002 │      15 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ a dispensary                 │        0.002 │      15 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ ii dispensary                │        0.002 │      12 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ referral hospital            │        0.002 │      10 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ ya                           │        0.002 │      10 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ lutheran dispensary          │        0.001 │       9 │
# ├──────────────────────────────┼──────────────┼─────────┤
# │ bakwata dispensary           │        0.001 │       9 │
# ╘══════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Togo
#
# ╒═════════════════════════════════════════════╤══════════════╤═════════╕
# │ Type                                        │   Proportion │   Count │
# ╞═════════════════════════════════════════════╪══════════════╪═════════╡
# │ unite de soins peripherique                 │        0.541 │     112 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre medicosocial                         │        0.246 │      51 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre hospitalier prefectoral              │        0.145 │      30 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ centre hospitalier regional                 │        0.024 │       5 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ tomegbe unite de soins peripherique         │        0.01  │       2 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ tove unite de soins peripherique            │        0.01  │       2 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ cope unite de soins peripherique            │        0.01  │       2 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ university centre hospitalier universitaire │        0.01  │       2 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ sokode centre hospitalier                   │        0.01  │       2 │
# ├─────────────────────────────────────────────┼──────────────┼─────────┤
# │ atakpame centre hospitalier                 │        0.01  │       2 │
# ╘═════════════════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Uganda
# ╒══════════════════════════════════╤══════════════╤═════════╕
# │ Type                             │   Proportion │   Count │
# ╞══════════════════════════════════╪══════════════╪═════════╡
# │ health centre ii                 │        0.557 │    2114 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ health centre iii                │        0.314 │    1192 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ health centre iv                 │        0.05  │     188 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ hospital                         │        0.029 │     109 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ medical centre health centre ii  │        0.004 │      16 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ ngo health centre ii             │        0.004 │      14 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ medical centre health centre iii │        0.003 │      13 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ mission health centre iii        │        0.003 │      13 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ clinic                           │        0.003 │      12 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ mission health centre ii         │        0.002 │       9 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ muslim health centre ii          │        0.002 │       8 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ sda health centre ii             │        0.002 │       8 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ regional referral hospital       │        0.002 │       8 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ cou health centre ii             │        0.002 │       7 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ community health centre ii       │        0.002 │       6 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ uganda health centre ii          │        0.002 │       6 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ st francis health centre         │        0.002 │       6 │
# ├──────────────────────────────────┼──────────────┼─────────┤
# │ st                               │        0.002 │       6 │
# ╘══════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Zambia
#
# ╒═══════════════════════════╤══════════════╤═════════╕
# │ Type                      │   Proportion │   Count │
# ╞═══════════════════════════╪══════════════╪═════════╡
# │ health post               │        0.65  │     821 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ rural health centre       │        0.085 │     107 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ health centre             │        0.078 │      98 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ clinic clinic             │        0.03  │      38 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ district level 1 hospital │        0.022 │      28 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ mission level 1 hospital  │        0.019 │      24 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ level 1 hospital          │        0.013 │      16 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ general level 2 hospital  │        0.006 │       8 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ urban clinic clinic       │        0.006 │       8 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ level 2 hospital          │        0.005 │       6 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ hc health centre          │        0.004 │       5 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ kawama health centre      │        0.003 │       4 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ urban health centre       │        0.003 │       4 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ mission level 2 hospital  │        0.002 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ chipepo health post       │        0.002 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ main health centre        │        0.002 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ chibote health post       │        0.002 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ mission health post       │        0.002 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ 2 health post             │        0.002 │       3 │
# ├───────────────────────────┼──────────────┼─────────┤
# │ mufulira clinic           │        0.002 │       3 │
# ╘═══════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Zanzibar
#
# ╒════════════════════════════════════╤══════════════╤═════════╕
# │ Type                               │   Proportion │   Count │
# ╞════════════════════════════════════╪══════════════╪═════════╡
# │ primary health care unit           │        0.862 │     125 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ mchangani primary health care unit │        0.028 │       4 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ primary health care centre         │        0.028 │       4 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ ngombe primary health care unit    │        0.014 │       2 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ ziwani primary health care unit    │        0.014 │       2 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ charawe primary health care unit   │        0.014 │       2 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ kidoti primary health care unit    │        0.014 │       2 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ district hospital                  │        0.014 │       2 │
# ├────────────────────────────────────┼──────────────┼─────────┤
# │ hospital                           │        0.014 │       2 │
# ╘════════════════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------
#
# Country:  Zimbabwe
#
# ╒════════════════════════╤══════════════╤═════════╕
# │ Type                   │   Proportion │   Count │
# ╞════════════════════════╪══════════════╪═════════╡
# │ clinic                 │        0.445 │     550 │
# ├────────────────────────┼──────────────┼─────────┤
# │ rural health clinic    │        0.4   │     495 │
# ├────────────────────────┼──────────────┼─────────┤
# │ rural hospital         │        0.084 │     104 │
# ├────────────────────────┼──────────────┼─────────┤
# │ district hospital      │        0.038 │      47 │
# ├────────────────────────┼──────────────┼─────────┤
# │ provincial hospital    │        0.006 │       7 │
# ├────────────────────────┼──────────────┼─────────┤
# │ central hospital       │        0.005 │       6 │
# ├────────────────────────┼──────────────┼─────────┤
# │ st                     │        0.005 │       6 │
# ├────────────────────────┼──────────────┼─────────┤
# │ ii rural health clinic │        0.004 │       5 │
# ├────────────────────────┼──────────────┼─────────┤
# │ i rural health clinic  │        0.003 │       4 │
# ╘════════════════════════╧══════════════╧═════════╛
#
# -------------------------------------------------------------------------------------

# %%
# Format the results from the common phrases finding process to a DataFrame
result_df = pd.DataFrame(country_and_common_facility_types.items(),columns=['Country','Type']).explode('Type')
result_df[['Type','Proportion within Country','Count']] = pd.DataFrame(result_df['Type'].tolist(), index = result_df.index)
result_df = result_df.sort_values(['Country','Proportion within Country'], ascending=[True, False]).reset_index(drop=True)
result_df.head(20)

# %% [markdown]
# During the Google Search process, take notes of the special abbreviation:
#
# - RCH : Reproductive Child Health
# - GFPA : Gambia Family Planning Association
# - AIC : Africa Inland Church
# - SDA : Seventh Day Adventist
# - PHC : Primary Health Care
# - FOSACOM : Formation Sanitaire Communautaire
# - OPD : Out-Patient Department
# - SRCS : Somali Red Crescent Society
# - CHC : Community Health Center
# - RC : Red Cross
# - ACK : Anglican Church of Kenya
# - UVS : Unites Villageoises de Sante
