# %%
import pandas as pd
import numpy as np
import re
import unidecode
from collections import Counter 

import reverse_geocoder
import pycountry

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Extract Common Phrases from Nature Dataset

# %%
# Read in the dataset   # $ updated
df = pd.read_csv('/Users/timsmac/Desktop/GRID3/B_semi_data/healthsites_world_african_part.csv',low_memory=False)
df.head()
# Out:
#        osm_id   amenity healthcare             name operator source  \
# 0  1433615056  pharmacy        NaN         dis-chem      NaN    NaN
# 1  1433904505  pharmacy        NaN              NaN      NaN    NaN
# 2  1434317784  pharmacy        NaN           clicks      NaN    NaN
# 3  1434394492  pharmacy        NaN           clicks      NaN    NaN
# 4  1435184422  pharmacy        NaN  Kenema Pharmacy      NaN    NaN
#
#   speciality operator_ty contact_num operational opening_hou  beds  \
# 0        NaN         NaN         NaN         NaN         NaN   NaN
# 1        NaN         NaN         NaN         NaN         NaN   NaN
# 2        NaN         NaN         NaN         NaN         NaN   NaN
# 3        NaN         NaN         NaN         NaN         NaN   NaN
# 4        NaN         NaN         NaN         NaN         NaN   NaN
#
#   staff_docto  staff_nurse health_amen dispensing wheelchair emergency  \
# 0         NaN          NaN         NaN        NaN        NaN       NaN
# 1         NaN          NaN         NaN        yes        NaN       NaN
# 2         NaN          NaN         NaN        NaN        NaN       NaN
# 3         NaN          NaN         NaN        NaN        NaN       NaN
# 4         NaN          NaN         NaN        yes        NaN       NaN
#
#   insurance water_sourc electricity is_in_healt is_in_healt_1  url  \
# 0       NaN         NaN         NaN         NaN           NaN  NaN
# 1       NaN         NaN         NaN         NaN           NaN  NaN
# 2       NaN         NaN         NaN         NaN           NaN  NaN
# 3       NaN         NaN         NaN         NaN           NaN  NaN
# 4       NaN         NaN         NaN         NaN           NaN  NaN
#
#   addr_housen addr_street addr_postco addr_city  changeset_i  changeset_v  \
# 0         NaN         NaN         NaN       NaN      9308758            1
# 1         NaN         NaN         NaN       NaN      9311970            1
# 2         NaN         NaN         NaN       NaN      9316364            1
# 3         NaN         NaN         NaN       NaN      9316364            1
# 4         NaN         NaN         NaN       NaN     11114428            2
#
#            changeset_t       changeset_u              coordinates  \
# 0  2011-09-15 16:26:54         Chris-Jan  [-26.267759, 28.051121]
# 1  2011-09-15 21:34:03    Javier Sanchez  [28.427018, -16.298639]
# 2  2011-09-16 13:55:27         Chris-Jan  [-26.179756, 28.117323]
# 3  2011-09-16 14:43:25         Chris-Jan  [-26.188383, 28.123669]
# 4  2012-03-27 09:38:52  AddisMap-Surafel    [9.014315, 38.757292]
#
#    within_africa
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %%
def deaccent(accented_string):
    return unidecode.unidecode(accented_string)

def remove_special_characters_and_shrink_whitespace(input_string):
    output_string = re.sub(r'\s+',' ',re.sub(r'[^A-Za-z0-9\s]','',input_string))
    return output_string

# %%
# $ updated

df.coordinates = df.coordinates.apply(eval)

def get_country_given_coordinates(coord): 
    coord = [tuple(li) for li in coord]
    results = reverse_geocoder.search(coord)
    return [pycountry.countries.get(alpha_2 = res['cc']).name for res in results]

# %%
df['Country'] = get_country_given_coordinates(df.coordinates.tolist())
# Out:
# Loading formatted geocoded file...

# %%
df.Country = df.Country.apply(deaccent).apply(str.lower)

# %%
african_countries = pd.read_csv('type_dict_tim.csv')['Country'].unique().tolist()

# %%
df = df[df.Country.isin(african_countries)].reset_index(drop=True)

# %%
df = df.sort_values('Country').reset_index(drop=True)

# %%
# Change column names to be more readable
df = df.rename(columns = {'name':'name','amenity':'Type'}) # $ updated
# Drop entries whose name field is missing or empty
df['name'] = df['name'].apply(lambda x: np.nan if isinstance(x,str) and x.strip() == '' else x)  # $ updated
df = df.dropna(subset=['name']).copy()
# De-accent the name field
df['deaccented_name'] = df['name'].apply(deaccent)
# Remove the special characters in the name field and reduce multiple whitespace to single one
df['special_char_removed_name'] = df['deaccented_name'].apply(remove_special_characters_and_shrink_whitespace)
# Make the name field lowercase
df['lowered_cleaned_name'] = df['special_char_removed_name'].apply(str.lower)

# %%
def get_unique_ngram(list_of_ordered_tokens, n):
    # Get the unique ngrams in a string, given a list of ordered tokens in that string
    return set(zip(*[list_of_ordered_tokens[i:i-(n-1)] if i<n-1 else list_of_ordered_tokens[n-1:] for i in range(0,n)]))

def reduce_nested_ngram_freq(x):    
    max_matched_n = 0 # Length of the longest ngram(s) we have matched for this name
    # Note that we have ordered the ngram_freq such that longer ngrams come first, so we can expect to match longest ngram asap
    
    for n, ngram, count in ngram_freq:
        # If the current ngram occurred in more than one name AND the ngram is in the current name
        if (count > 1) and (' '+ngram+' ' in ' '+x+' '):
            # If the current ngram is at least the same or even longer than the max n we matched, 
            # just update the max n and move on
            if n >= max_matched_n:
                max_matched_n = n                
            else:
            # Else if the current ngram is shorter than longest ngram we have matched in this name,
            # this probably suggests the current ngram is part of the longest ngram we matched before,
            # thus we need to decrease the frequency count for this shorter ngram as it is not an independent count
                mutable_ngram_freq[ngram] -= 1

# %%
# Get the unique countries in the dataset
list_of_countries = df['Country'].unique().tolist()

# Build a dictionary where entry key is the name of the country, 
# entry value is the list of health facility types in that country
country_and_common_facility_types = {}

# Iterate through all the unique countries
for country_name in list_of_countries:
    
    print('Country: ',country_name,'\n')

    # Get the part of the data that belongs to this country 
    country_part = df[df['Country']== country_name].copy()
    
    # Get the total number of health facilities in this country 
    total_facility_count_in_this_country = len(country_part)

    # Get the list of names of the facilities in this country
    name_list = country_part.lowered_cleaned_name.tolist()

    #------------------------------------------------------------------------------------------#
    phrase_counter = Counter()
    # For each name in the name list, tokenize it and count the ngrams in the name, 
    # and add the frequency of ngrams to the phrase counter
    for name in name_list:
        tokens_in_name = name.strip().split(" ")
        for n in range(1,10+1): # Record frequency of ngrams up to 10 tokens' long
            phrase_counter.update( get_unique_ngram(tokens_in_name, n) )
    
    # For each pair of (token_sequence, count) in the phrase_counter, convert it to (n, ngram, count), where n is the "n" in ngram
    ngram_freq = [(len(token_sequence),' '.join(token_sequence), count) for token_sequence, count in phrase_counter.most_common() if count >= round(len(name_list)*0.001)]
    #------------------------------------------------------------------------------------------#
    
    # Sort the ngram_freq list in the reverse order of n, such that longer ngrams is earlier in the list
    ngram_freq = sorted(ngram_freq, key = lambda entry: -entry[0])
  
    # Create a mutable copy of the ngram_freq list
    mutable_ngram_freq = {ngram : count for n, ngram, count in ngram_freq}

    # Iterate through all the names in the name list, use the reduce the frequency count for the ngrams that are part of longer ngram
    for name in name_list:
        reduce_nested_ngram_freq(name)
    
    common_facility_types_in_this_country = []
    minimum_proportion = 0.009
    for ngram, count in mutable_ngram_freq.items():
        # In some cases, there is only one instance of a special kind of health facility in a country. 
        # The criteria here will not capture that, thus it needs to be rediscovered in post processing.
        proportion_in_country = round(count/total_facility_count_in_this_country, 3)
        if count > 1 and proportion_in_country > minimum_proportion: 
            common_facility_types_in_this_country.append((ngram, proportion_in_country, count))

    # Order the list of most frequently occuring facility types by order of their proportion in country, highest comes first
    common_facility_types_in_this_country = sorted(common_facility_types_in_this_country, key = lambda x: -x[1])

    country_and_common_facility_types[country_name] = common_facility_types_in_this_country
    
    print(common_facility_types_in_this_country)
    
    print('----------------------------------\n')
# Out:
# Country:  angola
#
# [('farmacia', 0.451, 134), ('centro medico', 0.054, 16), ('clinica', 0.047, 14), ('consultorio medico', 0.024, 7), ('ii', 0.017, 5), ('centro de saude', 0.01, 3), ('deposito de medicamentos', 0.01, 3), ('hospital', 0.01, 3), ('mecofarma', 0.01, 3), ('das', 0.01, 3)]
# ----------------------------------
#
# Country:  benin
#
# [('pharmacie', 0.196, 84), ('clinique', 0.056, 24), ('centre de sante', 0.049, 21), ('centre de sante de', 0.042, 18), ('ong', 0.028, 12), ('centre medicosocial', 0.023, 10), ('de', 0.023, 10), ('pharmacie de', 0.021, 9), ('centre', 0.016, 7), ('sante', 0.016, 7), ('clinique saint', 0.014, 6), ('pharmacie le', 0.014, 6), ('saint', 0.014, 6), ('centre medical', 0.012, 5), ('cabinet dentaire', 0.012, 5), ('clinique st', 0.012, 5), ('benin', 0.012, 5)]
# ----------------------------------
#
# Country:  botswana
#
# [('clinic', 0.438, 42), ('health post', 0.104, 10), ('hospital', 0.104, 10), ('pharmacy', 0.062, 6), ('health clinic', 0.042, 4), ('medical centre', 0.031, 3), ('centre', 0.031, 3), ('taurus pharmacy', 0.021, 2), ('dental clinic', 0.021, 2), ('fine pharmaceuticals', 0.021, 2), ('dental', 0.021, 2), ('clicks', 0.021, 2), ('primary', 0.021, 2), ('siga', 0.021, 2)]
# ----------------------------------
#
# Country:  burkina faso
#
# [('csps de', 0.213, 98), ('pharmacie', 0.119, 55), ('csps', 0.054, 25), ('pharmacie du', 0.03, 14), ('dispensaire', 0.026, 12), ('clinique', 0.026, 12), ('pharmacie de', 0.02, 9), ('pharmacie de la', 0.017, 8), ('centre de sante et de promotion sociale', 0.011, 5), ('depot pharmaceutique', 0.011, 5), ('de', 0.011, 5)]
# ----------------------------------
#
# Country:  burundi
#
# [('cds', 0.299, 89), ('centre de sante de', 0.107, 32), ('centre de sante', 0.091, 27), ('pharmacie', 0.06, 18), ('poste de sante de', 0.04, 12), ('poste de sante', 0.017, 5), ('de', 0.017, 5), ('centre medical', 0.013, 4), ('clinique', 0.013, 4), ('saint', 0.013, 4), ('centre de', 0.01, 3), ('cds la', 0.01, 3), ('centre', 0.01, 3)]
# ----------------------------------
#
# Country:  cameroon
#
# [('pharmacie', 0.088, 64), ('centre de sante', 0.049, 36), ('centre medical', 0.036, 26), ('centre de sante integre de', 0.033, 24), ('pharmacy', 0.027, 20), ('pharmacie de', 0.025, 18), ('pharmacie de la', 0.021, 15), ('clinique', 0.021, 15), ('centre de sante de', 0.016, 12), ('clinic', 0.015, 11), ('centre de sante integre', 0.014, 10), ('centre de sante la', 0.014, 10), ('pharmacie du', 0.014, 10), ('cabinet medical', 0.014, 10), ('cabinet dentaire', 0.012, 9), ('health center', 0.011, 8), ('pharmacie la', 0.011, 8), ('de', 0.011, 8), ('centre de', 0.01, 7)]
# ----------------------------------
#
# Country:  central african republic
#
# [('poste de sante de', 0.28, 51), ('centre de sante de', 0.137, 25), ('centre de sante', 0.099, 18), ('poste de sante', 0.055, 10), ('ps', 0.049, 9), ('cs', 0.044, 8), ('ps de', 0.038, 7), ('de', 0.022, 4), ('pharmacie', 0.022, 4), ('centre de sante urbain de', 0.016, 3), ('hopital regional de', 0.016, 3), ('hopital prefectoral', 0.016, 3), ('cs de', 0.016, 3), ('hopital de', 0.016, 3), ('clinique', 0.016, 3), ('centre de sante prive eeb', 0.011, 2), ('sala de observacao', 0.011, 2), ('de sante saint', 0.011, 2), ('cds sosso nakombo', 0.011, 2), ('point palu', 0.011, 2), ('centre medical', 0.011, 2), ('centre', 0.011, 2), ('dispensaire', 0.011, 2), ('acabef', 0.011, 2)]
# ----------------------------------
#
# Country:  chad
#
# [('centre de sante de', 0.221, 36), ('centre de sante', 0.117, 19), ('pharmacie', 0.074, 12), ('hopital de', 0.049, 8), ('depot pharmaceutique', 0.043, 7), ('de', 0.037, 6), ('mstshf', 0.037, 6), ('sydly', 0.031, 5), ('centre', 0.025, 4), ('hopital', 0.025, 4), ('clinique', 0.025, 4), ('centre medical', 0.018, 3), ('centre sante aboudeia lmrkz lshy bw dy', 0.012, 2), ('hopital de district de', 0.012, 2), ('hopital provincial de moussoro', 0.012, 2), ('centre de sante nord', 0.012, 2), ('hopital de gore', 0.012, 2), ('hopital central', 0.012, 2), ('cabinet medical', 0.012, 2), ('pharmacie le', 0.012, 2), ('ps de', 0.012, 2), ('le', 0.012, 2), ('du', 0.012, 2), ('sopivet', 0.012, 2), ('des', 0.012, 2), ('dentaire', 0.012, 2), ('samaritain', 0.012, 2), ('csi', 0.012, 2)]
# ----------------------------------
#
# Country:  comoros
#
# [('pharmacie', 0.3, 9), ('cabinet medical', 0.1, 3), ('centre de sante', 0.067, 2), ('pharmacie des', 0.067, 2), ('pharma', 0.067, 2), ('sydly', 0.067, 2)]
# ----------------------------------
#
# Country:  congo
#
# [('pharmacie', 0.154, 38), ('csi', 0.138, 34), ('clinique', 0.045, 11), ('pharmacie de', 0.032, 8), ('centre de sante integre de', 0.028, 7), ('loandjili', 0.024, 6), ('pharmacie de la', 0.016, 4), ('clinique medicale', 0.016, 4), ('de', 0.016, 4), ('hopital', 0.016, 4), ('du', 0.016, 4), ('saint', 0.016, 4), ('ong', 0.016, 4), ('cms', 0.016, 4), ('pharmacie du palais', 0.012, 3), ('clinique les oliviers', 0.012, 3), ('hopital de', 0.012, 3), ('centre medical', 0.012, 3), ('pharmacie la', 0.012, 3), ('la', 0.012, 3), ('medical', 0.012, 3), ('dispensaire', 0.012, 3), ('le', 0.012, 3)]
# ----------------------------------
#
# Country:  cote d'ivoire
#
# [('pharmacie', 0.153, 221), ('centre medical', 0.045, 65), ('centre de sante', 0.03, 44), ('clinique', 0.03, 43), ('cabinet medical', 0.019, 28), ('pharmacie du', 0.018, 26), ('clinique medicale', 0.016, 23), ('pharmacie de', 0.015, 22), ('pharmacie saint', 0.013, 19), ('pharmacie des', 0.012, 17), ('pharmacie de la', 0.01, 15), ('cabinet dentaire', 0.01, 14), ('pharmacie les', 0.01, 14), ('infirmerie', 0.01, 15)]
# ----------------------------------
#
# Country:  djibouti
#
# [('de sante', 0.3, 3), ('de', 0.2, 2), ('pharmacie', 0.2, 2)]
# ----------------------------------
#
# Country:  equatorial guinea
#
# []
# ----------------------------------
#
# Country:  eritrea
#
# [('faaremaasi', 0.333, 3), ('sydly rqm 1', 0.222, 2), ('sydly', 0.222, 2), ('pharmacy', 0.222, 2)]
# ----------------------------------
#
# Country:  eswatini
#
# [('clinic', 0.235, 8), ('pharmacy', 0.176, 6), ('centro de saude de', 0.147, 5), ('hospital', 0.147, 5), ('red cross', 0.059, 2), ('childrens', 0.059, 2), ('mbabane', 0.059, 2), ('matsapha', 0.059, 2), ('clicks', 0.059, 2)]
# ----------------------------------
#
# Country:  ethiopia
#
# [('pharmacy', 0.327, 123), ('clinic', 0.069, 26), ('health center', 0.045, 17), ('drug store', 0.035, 13), ('hosepitaale', 0.027, 10), ('faaremaasi', 0.024, 9), ('solo da pharmacy', 0.021, 8), ('dental clinic', 0.021, 8), ('madexaanite madabere', 0.016, 6), ('theenaa thaabiyaa', 0.013, 5), ('higher clinic', 0.013, 5), ('makaakalanyaa kelinike', 0.013, 5), ('dr', 0.013, 5), ('st', 0.013, 5), ('hospital', 0.013, 5), ('madehaanite beete', 0.011, 4), ('kelinike', 0.011, 4)]
# ----------------------------------
#
# Country:  gabon
#
# [('pharmacie', 0.114, 28), ('clinique', 0.082, 20), ('cabinet medical', 0.069, 17), ('pharmacie du', 0.041, 10), ('cabinet', 0.037, 9), ('pharmacie de', 0.033, 8), ('clinique medicale', 0.024, 6), ('cabinet dentaire', 0.024, 6), ('polyclinique', 0.024, 6), ('de', 0.02, 5), ('cabinet des soins infirmiers', 0.016, 4), ('pharmacie du carrefour', 0.016, 4), ('pharmacie des', 0.016, 4), ('cabinet de soins', 0.012, 3), ('cabinet accouchement la', 0.012, 3), ('cabinet medical de', 0.012, 3), ('cabinet medical dr', 0.012, 3), ('cabinet medical chinois', 0.012, 3), ('de la', 0.012, 3), ('cabinet accouchement', 0.012, 3), ('centre medical', 0.012, 3), ('hopital de', 0.012, 3), ('de nkembo', 0.012, 3), ('clinique medicochirurgicale', 0.012, 3), ('pharmacie carrefour', 0.012, 3), ('de lalala', 0.012, 3), ('medical', 0.012, 3), ('la', 0.012, 3), ('sos', 0.012, 3), ('vision', 0.012, 3)]
# ----------------------------------
#
# Country:  gambia
#
# [('clinic', 0.15, 6), ('drug store', 0.1, 4), ('hospital', 0.1, 4), ('health', 0.1, 4), ('poste de sante', 0.05, 2), ('de sante de', 0.05, 2), ('stop step pharmacy', 0.05, 2), ('case de sante', 0.05, 2), ('stop step', 0.05, 2), ('community clinic', 0.05, 2), ('centre', 0.05, 2), ('center', 0.05, 2)]
# ----------------------------------
#
# Country:  ghana
#
# [('pharmacy', 0.282, 247), ('clinic', 0.099, 87), ('pharmacy limited', 0.025, 22), ('chemist', 0.021, 18), ('medical centre', 0.015, 13), ('hospital', 0.014, 12), ('chps', 0.014, 12), ('chips compound', 0.013, 11), ('health', 0.013, 11), ('ernest chemist', 0.011, 10), ('health center', 0.01, 9), ('medical center', 0.01, 9)]
# ----------------------------------
#
# Country:  guinea
#
# [('pharmacie', 0.422, 282), ('poste de sante de', 0.037, 25), ('clinique', 0.031, 21), ('clinic', 0.027, 18), ('cabinet medical', 0.024, 16), ('centre medical', 0.024, 16), ('centre de sante', 0.022, 15), ('centre de sante de', 0.021, 14), ('pharmacie de', 0.019, 13), ('poste de sante', 0.018, 12), ('cabinet dentaire', 0.018, 12), ('centre', 0.015, 10), ('pharmacie la', 0.013, 9), ('pharmacie hadja', 0.01, 7)]
# ----------------------------------
#
# Country:  kenya
# [('dispensary', 0.14, 129), ('chemist', 0.139, 128), ('medical clinic', 0.07, 65), ('clinic', 0.064, 59), ('pharmacy', 0.04, 37), ('health centre', 0.034, 31), ('medical centre', 0.023, 21), ('health center', 0.021, 19), ('hospital', 0.021, 19), ('medical center', 0.014, 13), ('centre', 0.012, 11), ('medical', 0.011, 10), ('medical services', 0.01, 9), ('health', 0.01, 9)]
# ----------------------------------
#
# Country:  lesotho
#
# [('clinic', 0.31, 13), ('pharmacy', 0.262, 11), ('health centre', 0.143, 6), ('care pharmacy', 0.048, 2), ('centre', 0.048, 2), ('dentist', 0.048, 2), ('doctor', 0.048, 2), ('chemist', 0.048, 2), ('seventh', 0.048, 2), ('adventist', 0.048, 2)]
# ----------------------------------
#
# Country:  liberia
#
# [('clinic', 0.368, 270), ('medicine store', 0.106, 78), ('community clinic', 0.049, 36), ('medical clinic', 0.035, 26), ('health center', 0.035, 26), ('town clinic', 0.03, 22), ('hospital', 0.025, 18), ('medical center', 0.016, 12), ('pharmacy', 0.014, 10), ('pharmacie', 0.011, 8), ('lucky pharmacy', 0.01, 7), ('drug store', 0.01, 7)]
# ----------------------------------
#
# Country:  madagascar
#
# [('pharmacie', 0.291, 85), ('csb ii', 0.137, 40), ('pharmacie de', 0.027, 8), ('fivarotampanafody', 0.027, 8), ('depot de medicaments', 0.021, 6), ('clinique', 0.021, 6), ('dr', 0.021, 6), ('pharmacie du', 0.017, 5), ('depots de medicaments', 0.014, 4), ('cabinet medical', 0.014, 4), ('csb', 0.014, 4), ('de', 0.014, 4), ('aina', 0.014, 4), ('centre de sante de base', 0.01, 3), ('centre hospitalier de reference regional', 0.01, 3), ('depot de medicament', 0.01, 3), ('pharmacie des', 0.01, 3), ('medical', 0.01, 3), ('pharmacy', 0.01, 3), ('dokotera', 0.01, 3)]
# ----------------------------------
#
# Country:  malawi
#
# [('centro de saude de', 0.289, 54), ('centro de saude', 0.102, 19), ('clinic', 0.08, 15), ('hospital', 0.059, 11), ('health centre', 0.048, 9), ('health center', 0.043, 8), ('posto de saude de', 0.032, 6), ('private clinic', 0.027, 5), ('pharmacy', 0.021, 4), ('ward', 0.021, 4), ('department', 0.021, 4), ('district hospital', 0.016, 3), ('medical clinic', 0.016, 3), ('dental clinic', 0.016, 3), ('pharmacies', 0.016, 3), ('qech', 0.016, 3), ('dispensary', 0.016, 3), ('banja la mtsogolo clinic', 0.011, 2), ('kamuzu central hospital', 0.011, 2), ('pharmalife pharmacies ltd', 0.011, 2), ('one stop pharmacy', 0.011, 2), ('mpiri health centre', 0.011, 2), ('drug store', 0.011, 2), ('private hospital', 0.011, 2), ('leo pharmacy', 0.011, 2), ('nkombezi clinic', 0.011, 2), ('centre', 0.011, 2), ('life', 0.011, 2), ('eye', 0.011, 2), ('community', 0.011, 2), ('paediatric', 0.011, 2)]
# ----------------------------------
#
# Country:  mali
#
# [('centre de sante communautaire de', 0.208, 220), ('pharmacie', 0.144, 153), ('cscom de', 0.054, 57), ('centre de sante communautaire', 0.044, 47), ('centre de sante de reference de', 0.038, 40), ('cabinet medical', 0.038, 40), ('clinique', 0.031, 33), ('centre de sante', 0.022, 23), ('cscom', 0.022, 23), ('officine', 0.014, 15), ('centre sante', 0.012, 13)]
# ----------------------------------
#
# Country:  mauritania
#
# [('sydly', 0.327, 16), ('yd', 0.082, 4), ('lsydl', 0.061, 3), ('centre de sante', 0.041, 2), ('cscom de', 0.041, 2), ('lmnr', 0.041, 2), ('lsnn', 0.041, 2), ('brys', 0.041, 2), ('pharmacie', 0.041, 2), ('el', 0.041, 2), ('lslm', 0.041, 2)]
# ----------------------------------
#
# Country:  mauritius
#
# [('pharmacy', 0.31, 61), ('pharmacie', 0.142, 28), ('green cross', 0.03, 6), ('cabinet medical', 0.03, 6), ('dr', 0.03, 6), ('dental clinic', 0.025, 5), ('pharma', 0.025, 5), ('pharmacie de', 0.02, 4), ('clinic', 0.02, 4), ('medi clinic', 0.015, 3), ('pharmacie la', 0.015, 3), ('care pharmacy', 0.015, 3), ('pharmacie du', 0.015, 3), ('medical', 0.015, 3), ('care', 0.015, 3), ('green cross medical laboratory', 0.01, 2), ('clinique du nord', 0.01, 2), ('clinique dentaire', 0.01, 2), ('pharmacie boundary', 0.01, 2), ('medical centre', 0.01, 2), ('st jean', 0.01, 2), ('cabinet dentaire', 0.01, 2), ('health centre', 0.01, 2), ('flacq hospital', 0.01, 2), ('grand bay', 0.01, 2), ('cabinet', 0.01, 2), ('hospital', 0.01, 2), ('st', 0.01, 2), ('health', 0.01, 2), ('mahebourg', 0.01, 2), ('cascavelle', 0.01, 2), ('center', 0.01, 2), ('primary', 0.01, 2), ('new', 0.01, 2), ('rose', 0.01, 2), ('sante', 0.01, 2)]
# ----------------------------------
#
# Country:  mozambique
#
# [('centro de saude de', 0.691, 442), ('centro de saude', 0.087, 56), ('farmacia', 0.048, 31), ('posto de saude de', 0.02, 13), ('centro de salud', 0.02, 13)]
# ----------------------------------
#
# Country:  namibia
#
# [('pharmacy', 0.327, 33), ('clinic', 0.099, 10), ('medical centre', 0.079, 8), ('dr', 0.069, 7), ('practice', 0.05, 5), ('medical', 0.03, 3), ('family practice', 0.02, 2), ('medicine world', 0.02, 2), ('dental service', 0.02, 2), ('bay pharmacy', 0.02, 2), ('health center', 0.02, 2), ('centre', 0.02, 2), ('dental', 0.02, 2), ('medikor', 0.02, 2), ('apotheke', 0.02, 2), ('nampharm', 0.02, 2), ('state', 0.02, 2), ('rhino', 0.02, 2), ('park', 0.02, 2), ('rundu', 0.02, 2)]
# ----------------------------------
#
# Country:  niger
#
# [('pharmacie', 0.186, 54), ('clinique', 0.062, 18), ('csi', 0.052, 15), ('pharmacie du', 0.038, 11), ('pharmacie populaire', 0.024, 7), ('cabinet medical', 0.024, 7), ('centre de sante integre', 0.021, 6), ('pharmacie de', 0.021, 6), ('centre', 0.021, 6), ('cabinet de soin', 0.017, 5), ('depot pharmaceutique', 0.017, 5), ('cabinet', 0.017, 5), ('cabinet de soins', 0.014, 4), ('pharmacie route', 0.014, 4), ('pharmacie des', 0.014, 4), ('cabinet medicale', 0.014, 4), ('de', 0.014, 4), ('hopital', 0.014, 4), ('phamacie', 0.014, 4), ('salle des soins', 0.01, 3), ('centre de', 0.01, 3), ('de soin', 0.01, 3), ('de la', 0.01, 3), ('pharmacie assalam', 0.01, 3), ('la', 0.01, 3), ('maternite', 0.01, 3), ('polyclinique', 0.01, 3), ('phc', 0.01, 3), ('sanitaire', 0.01, 3)]
# ----------------------------------
#
# Country:  nigeria
#
# [('dispensary', 0.134, 186), ('phc', 0.105, 145), ('health post', 0.089, 124), ('clinic', 0.076, 105), ('primary health centre', 0.057, 79), ('health clinic', 0.056, 77), ('general hospital', 0.028, 39), ('pharmacy', 0.028, 39), ('hospital', 0.024, 33), ('health centre', 0.022, 30), ('primary health care', 0.015, 21), ('heath post', 0.014, 20), ('primary health clinic', 0.011, 15), ('health center', 0.01, 14)]
# ----------------------------------
#
# Country:  rwanda
#
# [('pharmacy', 0.082, 4), ('de', 0.061, 3), ('poste de sante', 0.041, 2), ('tradi praticien', 0.041, 2), ('clinique', 0.041, 2), ('pharmacie', 0.041, 2)]
# ----------------------------------
#
# Country:  sao tome and principe
#
# [('posto de', 0.6, 6), ('nova apostolica', 0.2, 2), ('hospital', 0.2, 2)]
# ----------------------------------
#
# Country:  senegal
#
# [('pharmacie', 0.239, 182), ('poste de sante', 0.051, 39), ('clinique', 0.034, 26), ('case de sante de', 0.03, 23), ('case de sante', 0.025, 19), ('poste de sante de', 0.02, 15), ('centre de sante', 0.018, 14), ('pharmacie du', 0.016, 12), ('cabinet medical', 0.016, 12), ('cabinet dentaire', 0.016, 12), ('cabinet', 0.012, 9), ('pharmacie de la', 0.01, 8), ('dispensaire', 0.01, 8)]
# ----------------------------------
#
# Country:  seychelles
#
# [('euromedical family clinic', 0.167, 2), ('behrams pharmacy', 0.167, 2), ('pharmacy', 0.167, 2)]
# ----------------------------------
#
# Country:  sierra leone
#
# [('pharmacy', 0.098, 34), ('clinic', 0.081, 28), ('enterprise', 0.064, 22), ('mchp', 0.046, 16), ('hospital', 0.04, 14), ('health center', 0.038, 13), ('poste de sante', 0.026, 9), ('community health post', 0.023, 8), ('patent', 0.023, 8), ('community health center', 0.02, 7), ('community clinic', 0.02, 7), ('ministry of health and sanitation clinic', 0.017, 6), ('drug store', 0.017, 6), ('poste de sante de', 0.014, 5), ('health', 0.014, 5), ('maternal child health post', 0.012, 4), ('centre de sante', 0.012, 4), ('health centre', 0.012, 4), ('and', 0.012, 4), ('chp', 0.012, 4), ('mohamed', 0.012, 4)]
# ----------------------------------
#
# Country:  somalia
#
# [('hospital', 0.294, 5), ('pharmacy', 0.118, 2), ('center', 0.118, 2), ('mstshf', 0.118, 2), ('clinic', 0.118, 2)]
# ----------------------------------
#
# Country:  south africa
# [('clicks', 0.176, 158), ('pharmacy', 0.12, 108), ('clinic', 0.098, 88), ('dr', 0.05, 45), ('dischem', 0.048, 43), ('hospital', 0.024, 22), ('link', 0.02, 18), ('medical centre', 0.018, 16), ('apteek', 0.017, 15), ('dental', 0.013, 12), ('de', 0.012, 11), ('centre', 0.011, 10), ('clicks pharmacy', 0.01, 9), ('health', 0.01, 9), ('dentist', 0.01, 9)]
# ----------------------------------
#
# Country:  south sudan
#
# [('clinic', 0.174, 8), ('phcc', 0.174, 8), ('phcu', 0.152, 7), ('hospital', 0.109, 5), ('pharmacy', 0.087, 4), ('feeding centre', 0.065, 3), ('phu', 0.065, 3), ('primary healthcare', 0.043, 2), ('msf', 0.043, 2)]
# ----------------------------------
#
# Country:  sudan
#
# [('sydly', 0.432, 426), ('ltby', 0.026, 26), ('mrkz', 0.024, 24), ('mstshfy', 0.022, 22), ('lhdyth', 0.018, 18), ('sydly d', 0.017, 17), ('2', 0.014, 14), ('sydly bw', 0.012, 12), ('ltb lsnn', 0.011, 11), ('mstshf', 0.01, 10)]
# ----------------------------------
#
# Country:  togo
#
# [('pharmacie', 0.243, 83), ('cms', 0.044, 15), ('clinique', 0.041, 14), ('centre medicosocial', 0.029, 10), ('pharmacie du', 0.023, 8), ('dispensaire de', 0.023, 8), ('cabinet medical', 0.02, 7), ('dispensaire', 0.02, 7), ('pharmacie de', 0.018, 6), ('pharmacie des', 0.018, 6), ('la', 0.018, 6), ('centre de sante', 0.015, 5), ('pharmacie de la', 0.015, 5), ('de', 0.015, 5), ('centre', 0.015, 5), ('usp', 0.015, 5), ('polyclinique de', 0.012, 4), ('pharmacie le', 0.012, 4), ('et', 0.012, 4), ('saint', 0.012, 4)]
# ----------------------------------
#
# Country:  uganda
#
# [('drug shop', 0.107, 271), ('clinic', 0.078, 196), ('pharmacy', 0.066, 166), ('medical centre', 0.048, 122), ('hc iii', 0.047, 118), ('health centre', 0.039, 99), ('medical clinic', 0.034, 86), ('health centre ii', 0.033, 83), ('hc ii', 0.022, 55), ('health centre iii', 0.019, 49), ('medical center', 0.018, 45), ('hospital', 0.017, 44), ('health center ii', 0.016, 41), ('health center iii', 0.014, 35), ('health center', 0.014, 35), ('tradi praticien', 0.012, 30), ('dental clinic', 0.011, 27)]
# ----------------------------------
#
# Country:  zambia
#
# [('clinic', 0.222, 26), ('hospital', 0.111, 13), ('pharmacy', 0.068, 8), ('health centre', 0.051, 6), ('district hospital', 0.043, 5), ('rural health center', 0.034, 4), ('health center', 0.034, 4), ('link pharmacy', 0.026, 3), ('drug store', 0.026, 3), ('general hospital', 0.026, 3), ('medical', 0.026, 3), ('chemist', 0.026, 3), ('clinic for natural medicine', 0.017, 2), ('one stop centre', 0.017, 2), ('rural health post', 0.017, 2), ('centre de sante', 0.017, 2), ('rural health', 0.017, 2), ('kamwala clinic', 0.017, 2), ('urban clinic', 0.017, 2), ('health clinic', 0.017, 2), ('bcz katabe', 0.017, 2), ('mission hospital', 0.017, 2), ('health', 0.017, 2), ('centre', 0.017, 2), ('district', 0.017, 2), ('st', 0.017, 2), ('care', 0.017, 2), ('lusaka', 0.017, 2), ('matero', 0.017, 2), ('level', 0.017, 2), ('chelstone', 0.017, 2)]
# ----------------------------------
#
# Country:  zimbabwe
#
# [('centro de saude de', 0.207, 39), ('clinic', 0.176, 33), ('satellite clinic', 0.074, 14), ('polyclinic', 0.048, 9), ('posto de saude de', 0.032, 6), ('pharmacy', 0.032, 6), ('primary care clinic', 0.027, 5), ('family health services', 0.027, 5), ('rural health centre', 0.027, 5), ('hospital', 0.027, 5), ('mission hospital', 0.021, 4), ('medical centre', 0.021, 4), ('surgery', 0.021, 4), ('golden valley mine clinic', 0.016, 3), ('victoria falls', 0.016, 3), ('centros de saude de', 0.011, 2), ('dental clinic', 0.011, 2), ('south clinic', 0.011, 2), ('medical clinic', 0.011, 2), ('medical center', 0.011, 2), ('st michaels', 0.011, 2), ('health', 0.011, 2), ('center', 0.011, 2), ('dental', 0.011, 2), ('glenview', 0.011, 2), ('park', 0.011, 2), ('avondale', 0.011, 2), ('chinhoyi', 0.011, 2), ('section', 0.011, 2), ('patchway', 0.011, 2)]
# ----------------------------------

# %%
result_df = result_df.dropna(subset=['Type']).reset_index(drop=True)

# %%
# Format the results from the common phrases finding process to a DataFrame
result_df = pd.DataFrame(country_and_common_facility_types.items(),columns=['Country','Type'])
result_df = result_df.explode('Type')
result_df[['Type','Proportion within Country','Count']] = pd.DataFrame(result_df['Type'].tolist(), index = result_df.index)
result_df.Country = result_df.Country.apply(str.lower)
result_df.Type = result_df.Type.apply(str).apply(str.lower) # $ update
result_df = result_df.sort_values(['Country','Proportion within Country'], ascending=[True, False]).reset_index(drop=True)

# %%
result_df.head(20)
# Out:
#    Country                      Type  Proportion within Country  Count
# 0   angola                  farmacia                      0.451  134.0
# 1   angola             centro medico                      0.054   16.0
# 2   angola                   clinica                      0.047   14.0
# 3   angola        consultorio medico                      0.024    7.0
# 4   angola                        ii                      0.017    5.0
# 5   angola           centro de saude                      0.010    3.0
# 6   angola  deposito de medicamentos                      0.010    3.0
# 7   angola                  hospital                      0.010    3.0
# 8   angola                 mecofarma                      0.010    3.0
# 9   angola                       das                      0.010    3.0
# 10   benin                 pharmacie                      0.196   84.0
# 11   benin                  clinique                      0.056   24.0
# 12   benin           centre de sante                      0.049   21.0
# 13   benin        centre de sante de                      0.042   18.0
# 14   benin                       ong                      0.028   12.0
# 15   benin       centre medicosocial                      0.023   10.0
# 16   benin                        de                      0.023   10.0
# 17   benin              pharmacie de                      0.021    9.0
# 18   benin                    centre                      0.016    7.0
# 19   benin                     sante                      0.016    7.0

# %% [markdown]
# ### Computer aided correction

# %%
# From the result above, we can see that common phrases include tokens that might not 
# be description health facility type, but rather places where the facilities are at

# One solution is to check if the first token in the matched type is a place in that country
# or if the token has some speical meaning...

result_df['first_token'] = result_df['Type'].apply(lambda x: x.split()[0])

# To narrow the scope we need to check, first identify some tokens that are obviously part of facility type:
tokens_that_are_part_of_facility_type = ['health', 'centre', 'hospital', 'clinic', 'hopital', 'district', 'postos', 'st', 'community', 'centro', 'primary', 'ii', 'mission', 'rural', 'poste', '2', 'dispensaire', '1', 'dispensary', 'general', 'central', 'hospitais', 'government', 'provincial', 'i', 'basic', 'mini', 'town', 'polyclinique', 'regional', 'clinique', 'hospitalier', 'urbain', 'public', 'de', 'referral', 'new', 'maternal', 'catholique'] # print(result_df['first_token'].value_counts()[result_df['first_token'].value_counts()>1].index.tolist())

# The dataframe below contains the facility types that might not be a valid facility type.
potential_places_as_prefix = result_df[~result_df['first_token'].isin(tokens_that_are_part_of_facility_type)].copy()

# %%
from scraper_functions import *

# %%
# Automate the process of searching these token on Google, record our decision when seeing the search results

def ask_google(list_of_search_keyword, input_guide):
    answers = []
    for search_keyword in list_of_search_keyword:
        go_to_page(driver, 'https://www.google.com/search?q='+search_keyword)
        answers.append(input(input_guide))
        print('\n')
    return answers

list_of_search_keyword = (potential_places_as_prefix['Country'] + '+' + potential_places_as_prefix['first_token']).to_list()

answers = ask_google(list_of_search_keyword, 'Is this a place or place type or facility or unable to tell? (p/t/f/u)')
potential_places_as_prefix['category_of_first_token'] = answers

# %%
# # The recorded answers from previous run:
potential_places_as_prefix['category_of_first_token'] = list('ttfpppfttutuffuptuppupppufpppppuppppuuuutptpppptppppffpufupppppppufftfpfptuffffffuffftfttftftffuppppufpfffpffffppppppppppfpppppppppppfpppptpffpfffuutupupptfuufpuupppuupfuuupppfffppufppufppppp')

# %% [markdown]
# During the Google Search process, take notes of the special abbreviation:
#
# - RCH : Reproductive Child Health
# - GFPA : Gambia Family Planning Association
# - AIC : Africa Inland Church
# - SDA : Seventh Day Adventist
# - PHC : Primary Health Care
# - FOSACOM : Formation Sanitaire Communautaire
# - OPD : Out-Patient Department
# - SRCS : Somali Red Crescent Society
# - CHC : Community Health Center
# - RC : Red Cross
# - ACK : Anglican Church of Kenya
# - UVS : Unites Villageoises de Sante

# %%
# # Inspect the results from our Google Search process
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 'p']
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 't']
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 'f']
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 'u']

# %%
# Map the category we recorded back to the main result dataframe
token_to_category_mapping = potential_places_as_prefix.set_index('first_token')['category_of_first_token'].to_dict()
result_df['category_of_first_token'] = result_df['first_token'].apply(lambda x: token_to_category_mapping.get(x, 'f'))
result_df['category_of_first_token'].value_counts()

# %%
# Identify the facility types that are common enough to be considered new facility types
new_facility_types = ['municipal hospital', 'sede health centre', 'vaz postos sanitarios', 'pedro postos sanitarios', 'est centre de sante', 'gare centre de sante integre', 'adi health station', 'sud health centre', 'area health centre', 'sud poste de sante', 'county hospital'] # print(result_df.loc[result_df['category_of_first_token']=='t','Type'].tolist())
result_df.loc[result_df['Type'].isin(new_facility_types), 'category_of_first_token'] = 'f'
result_df.loc[result_df['Type'].apply(lambda x: x.isnumeric()), 'category_of_first_token'] = 'u'
result_df = result_df[~result_df['category_of_first_token'].isin(['p', 't', 'u'])].reset_index(drop=True).drop(['first_token','category_of_first_token'], axis=1)

# %%
result_df.to_csv('../B_semi_data/type_dict_tim.csv',index=False)

# %%
result_df['Country-Type'] = result_df['Country'] + ' - ' +result_df['Type']

# %% [markdown]
# ### Compare extracted types with type_dict_augmented_1130

# %%
type_dict_1130 = pd.read_csv('../github_downloaded_datasets/type_dict_augmented_1130.csv')
type_dict_1130.Country = type_dict_1130.Country.apply(str.lower)
type_dict_1130.Type = type_dict_1130.Type.apply(str.lower)
type_dict_1130 = type_dict_1130.sort_values(['Country','Type']).reset_index(drop=True)
type_dict_1130['Country-Type'] = type_dict_1130['Country'] + ' - ' +type_dict_1130['Type']

# %%
assert(sorted(result_df.Country.unique().tolist()) == sorted(type_dict_1130.Country.unique().tolist()))

# %%
agreed_country_types = result_df[result_df['Country-Type'].isin(type_dict_1130['Country-Type'].tolist())].reset_index(drop=True)

agreed_country_types

# %%
unique_to_type_dict_1130 = type_dict_1130[~type_dict_1130['Country-Type'].isin(result_df['Country-Type'].tolist())].reset_index(drop=True)

unique_to_type_dict_1130

# %%
df[(df.Country=='angola')&(df.lowered_cleaned_name.str.contains('centro de saude'))]

# %%
unique_to_result_df = result_df[~result_df['Country-Type'].isin(type_dict_1130['Country-Type'].tolist())].reset_index(drop=True)

unique_to_result_df

# %% [markdown]
# ### Compare extracted types with the types that comes with nature dataset

# %%
country_to_facility_types_mapping = result_df.groupby('Country').agg({'Type':list}).to_dict()['Type']

# %%
def get_matched_type_and_pure_name(country_name, name):

    facility_types = country_to_facility_types_mapping[country_name]

    facility_types = sorted(facility_types, key = lambda x: -len(x.split()))

    matched_type = np.nan
    for facility_type in facility_types:
        if ' '+facility_type+' ' in ' '+name+' ':
            matched_type = facility_type
            break

    if isinstance(matched_type,str):
        pure_name = name.replace(matched_type,'').strip()
    else:
        pure_name = np.nan
        
    return (matched_type,pure_name)

# %%
df['Type'] = df['Type'].apply(str.lower).apply(deaccent)

df[['matched_type','pure_name']] = pd.DataFrame(df[['Country','lowered_cleaned_name']].apply(lambda row: get_matched_type_and_pure_name(row['Country'].lower(), row['lowered_cleaned_name']), axis=1).tolist(), index= df.index)

# %%
print('\n'+str(np.round(df.matched_type.notnull().mean()*100,2))+'% of the nature dataset is covered by the extracted types.')

print('\nFor '+str(np.round(sum(df.Type==df.matched_type)/len(df)*100,2))+'% of the nature dataset, provided type and extracted type are exactly the same.')

different_type = df.loc[(df.Type!=df.matched_type) & df.Type.notnull() & df.matched_type.notnull(), ['Country','name','Type','matched_type']]

print('\nFor '+str(np.round(len(different_type)/len(df)*100,2))+'% of the nature dataset, the provided type and extracted type are different. Below are some examples:\n')

different_type.drop_duplicates(subset=['Type','matched_type']).rename(columns={'Type':'original_type'})[:20]
