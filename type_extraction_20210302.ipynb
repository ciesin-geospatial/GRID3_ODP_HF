# %%
import pandas as pd
import numpy as np
import re
import unidecode
from collections import Counter

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Extract Common Phrases from Nature Dataset

# %%
# Read in the dataset
df = pd.read_csv('/Users/timsmac/Desktop/GRID3/B_semi_data/sub-saharan_health_facilities.csv')
df.head()
# Out:
#   Country Admin1                         Facility n          Facility t  \
# 0  Angola  Bengo            Hospital Barra Do Dande            Hospital
# 1  Angola  Bengo                Hospital Dos Dembos            Hospital
# 2  Angola  Bengo       Hospital Municipal de Ambriz  Municipal Hospital
# 3  Angola  Bengo  Hospital Municipal de Bula Atumba  Municipal Hospital
# 4  Angola  Bengo        Hospital Municipal de Dande  Municipal Hospital
#
#   Ownership     Lat     Long     LL source         coordinates
# 0     Govt. -8.6560  13.4919  Google Earth   [-8.656, 13.4919]
# 1     Govt. -8.5026  14.5862  Google Earth  [-8.5026, 14.5862]
# 2     Govt. -7.8522  13.1307  Google Earth  [-7.8522, 13.1307]
# 3     Govt. -8.6742  14.7925  Google Earth  [-8.6742, 14.7925]
# 4     Govt. -8.5835  13.6569  Google Earth  [-8.5835, 13.6569]

# %%
def deaccent(accented_string):
    return unidecode.unidecode(accented_string)

def remove_special_characters_and_shrink_whitespace(input_string):
    output_string = re.sub(r'\s+',' ',re.sub(r'[^A-Za-z0-9\s]','',input_string))
    return output_string

# Change column names to be more readable
df = df.rename(columns = {'Facility n':'name','Facility t':'Type'})
# Drop entries whose name field is missing or empty
df['name'] = df['name'].apply(lambda x: np.nan if x.strip() == '' else x)
df = df.dropna(subset=['name']).copy()
# De-accent the name field
df['deaccented_name'] = df['name'].apply(deaccent)
# Remove the special characters in the name field and reduce multiple whitespace to single one
df['special_char_removed_name'] = df['deaccented_name'].apply(remove_special_characters_and_shrink_whitespace)
# Make the name field lowercase
df['lowered_cleaned_name'] = df['special_char_removed_name'].apply(str.lower)

# %%
def get_unique_ngram(list_of_ordered_tokens, n):
    # Get the unique ngrams in a string, given a list of ordered tokens in that string
    return set(zip(*[list_of_ordered_tokens[i:i-(n-1)] if i<n-1 else list_of_ordered_tokens[n-1:] for i in range(0,n)]))

def reduce_nested_ngram_freq(x):    
    max_matched_n = 0 # Length of the longest ngram(s) we have matched for this name
    # Note that we have ordered the ngram_freq such that longer ngrams come first, so we can expect to match longest ngram asap
    
    for n, ngram, count in ngram_freq:
        # If the current ngram occurred in more than one name AND the ngram is in the current name
        if (count > 1) and (' '+ngram+' ' in ' '+x+' '):
            # If the current ngram is at least the same or even longer than the max n we matched, 
            # just update the max n and move on
            if n >= max_matched_n:
                max_matched_n = n                
            else:
            # Else if the current ngram is shorter than longest ngram we have matched in this name,
            # this probably suggests the current ngram is part of the longest ngram we matched before,
            # thus we need to decrease the frequency count for this shorter ngram as it is not an independent count
                mutable_ngram_freq[ngram] -= 1

# %%
# Get the unique countries in the dataset
list_of_countries = df['Country'].unique().tolist()

# Build a dictionary where entry key is the name of the country, 
# entry value is the list of health facility types in that country
country_and_common_facility_types = {}

# Iterate through all the unique countries
for country_name in list_of_countries:
    
    print('Country: ',country_name,'\n')

    # Get the part of the data that belongs to this country 
    country_part = df[df['Country']== country_name].copy()
    
    # Get the total number of health facilities in this country 
    total_facility_count_in_this_country = len(country_part)

    # Get the list of names of the facilities in this country
    name_list = country_part.lowered_cleaned_name.tolist()

    #------------------------------------------------------------------------------------------#
    phrase_counter = Counter()
    # For each name in the name list, tokenize it and count the ngrams in the name, 
    # and add the frequency of ngrams to the phrase counter
    for name in name_list:
        tokens_in_name = name.strip().split(" ")
        for n in range(1,10+1): # Record frequency of ngrams up to 10 tokens' long
            phrase_counter.update( get_unique_ngram(tokens_in_name, n) )
    
    # For each pair of (token_sequence, count) in the phrase_counter, convert it to (n, ngram, count), where n is the "n" in ngram
    ngram_freq = [(len(token_sequence),' '.join(token_sequence), count) for token_sequence, count in phrase_counter.most_common() if count >= round(len(name_list)*0.001)]
    #------------------------------------------------------------------------------------------#
    
    # Sort the ngram_freq list in the reverse order of n, such that longer ngrams is earlier in the list
    ngram_freq = sorted(ngram_freq, key = lambda entry: -entry[0])
  
    # Create a mutable copy of the ngram_freq list
    mutable_ngram_freq = {ngram : count for n, ngram, count in ngram_freq}

    # Iterate through all the names in the name list, use the reduce the frequency count for the ngrams that are part of longer ngram
    for name in name_list:
        reduce_nested_ngram_freq(name)
    
    common_facility_types_in_this_country = []
    minimum_proportion = 0.005
    for ngram, count in mutable_ngram_freq.items():
        # In some cases, there is only one instance of a special kind of health facility in a country. 
        # The criteria here will not capture that, thus it needs to be rediscovered in post processing.
        proportion_in_country = round(count/total_facility_count_in_this_country, 3)
        if count > 1 and proportion_in_country > minimum_proportion: 
            common_facility_types_in_this_country.append((ngram, proportion_in_country, count))

    # Order the list of most frequently occuring facility types by order of their proportion in country, highest comes first
    common_facility_types_in_this_country = sorted(common_facility_types_in_this_country, key = lambda x: -x[1])

    country_and_common_facility_types[country_name] = common_facility_types_in_this_country
    
    print(common_facility_types_in_this_country)
    
    print('----------------------------------\n')
# Out:
# Country:  Angola
#
# [('health post', 0.59, 929), ('health centre', 0.121, 191), ('municipal hospital', 0.047, 74), ('centro materno infantil', 0.026, 41), ('hospital', 0.018, 28), ('hospital municipal de', 0.014, 22), ('sede health centre', 0.008, 12)]
# ----------------------------------
#
# Country:  Benin
#
# [('centre de sante darrondissement', 0.366, 300), ('centre de sante', 0.295, 242), ('centre communal de sante', 0.161, 132), ('dispensaire', 0.031, 25), ('centre medical', 0.027, 22), ('hopital de zone', 0.026, 21), ('hopital', 0.022, 18), ('uvs unites de sante de village', 0.011, 9), ('centre de sante central', 0.011, 9), ('centre de sante de sousprefecture', 0.01, 8), ('centre hospitalier departemental', 0.006, 5)]
# ----------------------------------
#
# Country:  Botswana
#
# [('health post', 0.513, 320), ('clinic', 0.357, 223), ('primary hospital', 0.027, 17), ('district hospital', 0.011, 7)]
# ----------------------------------
#
# Country:  Burkina Faso
#
# [('centre de sante et de promotion sociale', 0.787, 1355), ('dispensaire', 0.043, 74), ('centre medical avec antenne chirurgicale', 0.028, 49), ('centre medical', 0.022, 38), ('urbain centre de sante et de promotion sociale', 0.006, 10)]
# ----------------------------------
#
# Country:  Burundi
#
# [('centre de sante', 0.705, 469), ('hopital de district', 0.069, 46), ('i centre de sante', 0.015, 10), ('ii centre de sante', 0.011, 7), ('mubuga centre de sante', 0.006, 4), ('nyarunazi centre de sante', 0.006, 4), ('kivoga centre de sante', 0.006, 4)]
# ----------------------------------
#
# Country:  Cameroon
#
# [('centre de sante integre', 0.658, 2014), ('centre medical darrondissement', 0.07, 215), ('centre de sante', 0.054, 166), ('hopital de district', 0.053, 162), ('catholique centre de sante', 0.023, 71), ('2 centre de sante integre', 0.011, 35), ('1 centre de sante integre', 0.01, 31), ('catholique dispensaire', 0.007, 21), ('ii centre de sante integre', 0.006, 18), ('eec centre de sante', 0.006, 19)]
# ----------------------------------
#
# Country:  Cape Verde
#
# [('centro de saude', 0.47, 31), ('postos sanitarios', 0.333, 22), ('hospitais regionais', 0.106, 7), ('vaz postos sanitarios', 0.03, 2), ('pedro postos sanitarios', 0.03, 2), ('hospitais centrais', 0.03, 2)]
# ----------------------------------
#
# Country:  Central African Republic
#
# [('poste de sante', 0.56, 311), ('centre de sante c', 0.103, 57), ('centre de sante e', 0.099, 55), ('centre de sante b', 0.076, 42), ('centre de sante a', 0.074, 41), ('hopital prefectoraux', 0.022, 12), ('hopital regional universitaire', 0.009, 5), ('disp poste de sante', 0.007, 4), ('i poste de sante', 0.007, 4)]
# ----------------------------------
#
# Country:  Chad
#
# [('centre de sante', 0.804, 1031), ('hopital de district', 0.055, 70), ('urbain centre de sante', 0.018, 23), ('ii centre de sante', 0.01, 13), ('est centre de sante', 0.008, 10), ('nord centre de sante', 0.007, 9)]
# ----------------------------------
#
# Country:  Comoros
#
# [('postes de sante', 0.682, 45), ('centre de sante', 0.182, 12), ('centre medicourbain', 0.045, 3), ('centre hospitalier regional', 0.03, 2), ('centre medicochirurgical', 0.03, 2)]
# ----------------------------------
#
# Country:  Congo
#
# [('centre de sante integre', 0.747, 245), ('lhopital de base', 0.03, 10), ('ii centre de sante integre', 0.027, 9), ('hopital comboutique', 0.027, 9), ('centr centre de sante integre', 0.018, 6), ('hopital general', 0.012, 4), ('kayes centre de sante integre', 0.009, 3), ('gare centre de sante integre', 0.009, 3), ('i centre de sante integre', 0.009, 3), ('st centre de sante integre', 0.009, 3), ('poste centre de sante integre', 0.006, 2), ('mouindi centre de sante integre', 0.006, 2), ('moussanda centre de sante integre', 0.006, 2), ('kibouende centre de sante integre', 0.006, 2), ('q34 centre de sante integre', 0.006, 2), ('oyo centre de sante integre', 0.006, 2), ('kelle centre de sante integre', 0.006, 2), ('mbomo centre de sante integre', 0.006, 2), ('garnison centre de sante integre', 0.006, 2), ('iii centre de sante integre', 0.006, 2), ('boko centre de sante integre', 0.006, 2), ('kinkala centre de sante integre', 0.006, 2), ('loumo centre de sante integre', 0.006, 2), ('mayama centre de sante integre', 0.006, 2), ('ngabe centre de sante integre', 0.006, 2), ('hopital', 0.006, 2)]
# ----------------------------------
#
# Country:  Cote d'Ivoire
#
# [('centre de sante rural', 0.694, 1244), ('centre de sante urbain', 0.15, 269), ('hopital general', 0.039, 70), ('hospitalier regional', 0.011, 19), ('centre medicosocial', 0.009, 17), ('2 centre de sante rural', 0.006, 11)]
# ----------------------------------
#
# Country:  Democratic Republic of the Congo
#
# [('centre de sante', 0.54, 7877), ('poste de sante', 0.266, 3879), ('centre medical', 0.055, 805), ('centre de sante de reference', 0.031, 454), ('hopital general de reference', 0.023, 340), ('clinique', 0.012, 168), ('dispensaire', 0.009, 127), ('polyclinique', 0.007, 97)]
# ----------------------------------
#
# Country:  Djibouti
#
# [('health post', 0.621, 41), ('community health centre', 0.182, 12), ('hospital', 0.136, 9), ('hospital medical centre', 0.045, 3), ('al', 0.03, 2)]
# ----------------------------------
#
# Country:  Equatorial Guinea
#
# [('district hospital', 0.234, 11), ('kientem', 0.17, 8), ('litoral', 0.128, 6), ('welenzas', 0.128, 6), ('bioko norte', 0.085, 4), ('centro sur', 0.085, 4), ('provincial hospital', 0.085, 4), ('1', 0.064, 3), ('2', 0.064, 3), ('3', 0.064, 3), ('4', 0.064, 3), ('5', 0.064, 3), ('6', 0.064, 3), ('public regional hospital', 0.043, 2), ('sur 1', 0.043, 2)]
# ----------------------------------
#
# Country:  Eritrea
#
# [('health station', 0.658, 177), ('health centre', 0.193, 52), ('hospital', 0.052, 14), ('mini hospital', 0.019, 5), ('clinic', 0.015, 4), ('alebu health station', 0.007, 2), ('adi health station', 0.007, 2), ('dekemhare health station', 0.007, 2), ('saba health station', 0.007, 2), ('mai dma health', 0.007, 2), ('kerkebet health', 0.007, 2), ('adi qeyh', 0.007, 2), ('forto health', 0.007, 2), ('mini clinic', 0.007, 2), ('tsorona health', 0.007, 2), ('referral hospital', 0.007, 2), ('health clinic', 0.007, 2), ('godaif health', 0.007, 2), ('ghinda health', 0.007, 2)]
# ----------------------------------
#
# Country:  eSwatini
#
# [('clinic', 0.644, 87), ('nazarene clinic', 0.111, 15), ('public health unit', 0.059, 8), ('health centre', 0.059, 8), ('st', 0.044, 6), ('community clinic', 0.022, 3), ('hospital', 0.022, 3), ('salvation army clinic', 0.015, 2), ('piggs peak', 0.015, 2), ('giving life', 0.015, 2), ('government hospital', 0.015, 2), ('mission clinic', 0.015, 2), ('nazerene clinic', 0.015, 2), ('ekuphileni', 0.015, 2), ('new', 0.015, 2), ('zombodze', 0.015, 2)]
# ----------------------------------
#
# Country:  Ethiopia
#
# [('clinic', 0.483, 2520), ('health post', 0.176, 917), ('health centre', 0.138, 720), ('health station', 0.026, 138), ('hospital', 0.024, 125), ('arada clinic', 0.009, 49), ('kolfe keraniyo clinic', 0.008, 43), ('bole clinic', 0.008, 44), ('nefas silk lafto clinic', 0.007, 38), ('yeka clinic', 0.007, 38), ('clinic 1', 0.006, 29), ('clinic 2', 0.006, 29), ('kirkos clinic', 0.006, 33)]
# ----------------------------------
#
# Country:  Gabon
#
# [('dispensaire', 0.614, 333), ('centre de sante', 0.17, 92), ('centre medical', 0.074, 40), ('1 dispensaire', 0.02, 11), ('hospitalier regional', 0.017, 9), ('2 dispensaire', 0.015, 8), ('12 dispensaire', 0.009, 5), ('ii dispensaire', 0.007, 4), ('centre de sante urbain', 0.006, 3)]
# ----------------------------------
#
# Country:  Gambia
#
# [('clinic', 0.408, 42), ('minor health centre', 0.359, 37), ('major health centre', 0.068, 7), ('hospital', 0.039, 4), ('kunda minor health centre', 0.029, 3), ('rch minor health centre', 0.019, 2), ('karantaba minor health centre', 0.019, 2), ('gfpa clinic', 0.019, 2), ('jeswang clinic', 0.019, 2), ('general hospital', 0.019, 2), ('kunda', 0.019, 2), ('for', 0.019, 2)]
# ----------------------------------
#
# Country:  Ghana
#
# [('health centre', 0.334, 654), ('communitybased health planning and services', 0.31, 608), ('clinic', 0.074, 145), ('community clinic', 0.034, 66), ('rural clinic', 0.031, 60), ('district hospital', 0.027, 52), ('hospital', 0.018, 36), ('government district hospital', 0.012, 23), ('methodist clinic', 0.007, 13), ('polyclinic', 0.007, 13), ('sda clinic', 0.006, 11), ('st', 0.006, 12)]
# ----------------------------------
#
# Country:  Guinea
# [('poste de sante', 0.604, 1055), ('centre de sante', 0.228, 398), ('hopital prefectoral', 0.014, 25)]
# ----------------------------------
#
# Country:  Guinea Bissau
#
# [('hospital regional de', 0.375, 3), ('hospital', 0.375, 3), ('hospital de', 0.25, 2), ('de', 0.25, 2)]
# ----------------------------------
#
# Country:  Kenya
#
# [('dispensary', 0.637, 3915), ('health centre', 0.154, 947), ('clinic', 0.027, 167), ('district hospital', 0.019, 118), ('subdistrict hospital', 0.017, 105), ('catholic dispensary', 0.016, 100), ('hospital', 0.013, 82), ('st', 0.011, 66), ('ack dispensary', 0.008, 52), ('community dispensary', 0.007, 46), ('aic dispensary', 0.007, 40), ('mission dispensary', 0.006, 37), ('mission hospital', 0.006, 36)]
# ----------------------------------
#
# Country:  Lesotho
#
# [('health centre', 0.769, 90), ('hospital', 0.154, 18), ('st theresa health centre', 0.026, 3), ('sda health centre', 0.017, 2), ('filter clinic', 0.017, 2), ('st josephs', 0.017, 2), ('st james', 0.017, 2)]
# ----------------------------------
#
# Country:  Liberia
#
# [('town', 0.112, 83), ('community', 0.023, 17), ('clinic', 0.012, 9), ('mission', 0.012, 9), ('hospital', 0.011, 8), ('st', 0.009, 7), ('village', 0.009, 7), ('medical centre', 0.008, 6), ('camp', 0.008, 6), ('1', 0.008, 6), ('city', 0.008, 6), ('new', 0.008, 6), ('memorial', 0.007, 5)]
# ----------------------------------
#
# Country:  Madagascar
#
# [('health centre', 0.534, 1429), ('health post', 0.303, 810), ('hospital', 0.044, 117), ('sud health centre', 0.007, 19), ('ii health post', 0.006, 16)]
# ----------------------------------
#
# Country:  Malawi
#
# [('health centre', 0.66, 428), ('dispensary', 0.116, 75), ('hospital', 0.037, 24), ('rural hospital', 0.035, 23), ('clinic', 0.035, 23), ('district hospital', 0.034, 22), ('st', 0.008, 5), ('health post', 0.006, 4), ('central hospital', 0.006, 4)]
# ----------------------------------
#
# Country:  Mali
#
# [('community health centre', 0.767, 1133), ('referral health centre', 0.041, 61), ('clinique', 0.04, 59), ('central community health centre', 0.024, 35), ('medicale clinique', 0.009, 14), ('hopital', 0.007, 11), ('polyclinique', 0.006, 9)]
# ----------------------------------
#
# Country:  Mauritania
#
# [('health post', 0.721, 465), ('health centre', 0.116, 75), ('hospital', 0.022, 14), ('health post i', 0.014, 9), ('2 health post', 0.012, 8), ('health post ii', 0.008, 5), ('health post iii', 0.008, 5), ('health post iv', 0.006, 4), ('health post v', 0.006, 4), ('general hospital', 0.006, 4)]
# ----------------------------------
#
# Country:  Mauritius
#
# [('community health centre', 0.669, 111), ('area health centre', 0.157, 26), ('regional hospital', 0.03, 5), ('family health clinic', 0.018, 3), ('district hospital', 0.018, 3), ('grand baie community health centre', 0.012, 2), ('de masque community health centre', 0.012, 2), ('leal community health centre', 0.012, 2), ('sables community health centre', 0.012, 2), ('bois community health centre', 0.012, 2), ('cocos community health centre', 0.012, 2), ('tamarin community health centre', 0.012, 2), ('dr h malher', 0.012, 2), ('community hospital', 0.012, 2)]
# ----------------------------------
#
# Country:  Mozambique
#
# [('centro de saude rural ii', 0.584, 922), ('posto de saude', 0.16, 252), ('centro de saude rural i', 0.079, 124), ('centro de saude urbano b', 0.032, 50), ('centro de saude urbano c', 0.029, 46), ('centro de saude urbano a', 0.02, 32), ('hospital rural', 0.016, 26), ('hospital distrital', 0.009, 15)]
# ----------------------------------
#
# Country:  Namibia
#
# [('clinic', 0.756, 279), ('health centre', 0.117, 43), ('district hospital', 0.079, 29), ('hospital', 0.011, 4), ('bay clinic', 0.008, 3), ('intermediate hospital', 0.008, 3), ('phc clinic', 0.008, 3)]
# ----------------------------------
#
# Country:  Niger
#
# [('health hut', 0.605, 1747), ('integrated health centre', 0.276, 797), ('hospital', 0.014, 41), ('koira health hut', 0.006, 16)]
# ----------------------------------
#
# Country:  Nigeria
#
# [('primary health centre', 0.215, 4476), ('health centre', 0.155, 3221), ('dispensary', 0.148, 3076), ('health post', 0.14, 2907), ('health clinic', 0.132, 2741), ('clinic', 0.051, 1063), ('basic health centre', 0.029, 593), ('general hospital', 0.025, 523), ('comprehensive health centre', 0.021, 427), ('primary health clinic', 0.014, 299), ('health facility', 0.008, 161), ('hospital', 0.008, 161), ('basic health clinic', 0.007, 145), ('cottage hospital', 0.007, 146), ('primary health care', 0.006, 126), ('model health centre', 0.006, 135)]
# ----------------------------------
#
# Country:  Rwanda
#
# [('health centre', 0.666, 381), ('district hospital', 0.063, 36), ('health post', 0.037, 21), ('fosacom communityowned health facility', 0.017, 10), ('nyamasheke health centre', 0.012, 7), ('kirehe health centre', 0.01, 6), ('nyanza health centre', 0.01, 6), ('gicumbi health centre', 0.009, 5), ('nyamagabe health centre', 0.009, 5), ('gakenke health centre', 0.007, 4), ('gatsibo health centre', 0.007, 4), ('nyagatare health centre', 0.007, 4), ('rwamagana health centre', 0.007, 4), ('nyarugenge health centre', 0.007, 4), ('national referral hospital', 0.007, 4), ('burera health centre', 0.007, 4), ('gisagara health centre', 0.007, 4), ('huye health centre', 0.007, 4), ('rubavu health centre', 0.007, 4), ('rutsiro health centre', 0.007, 4), ('provincial hospital', 0.007, 4)]
# ----------------------------------
#
# Country:  Sao Tome and Principe
#
# [('caue postos de saude comunitaria', 0.14, 7), ('postos de saude 2', 0.12, 6), ('postos de saude 3', 0.12, 6), ('mezoxi postos de saude', 0.12, 6), ('agua grande postos de saude', 0.1, 5), ('postos de saude 1', 0.1, 5), ('lobata postos de saude comunitaria', 0.08, 4), ('lobata postos de saude', 0.08, 4), ('postos de saude 4', 0.08, 4), ('cantagalo postos de saude', 0.08, 4), ('centros de saude', 0.08, 4), ('postos de saude comunitaria 5', 0.06, 3), ('caue postos de saude', 0.06, 3), ('lemba postos de saude', 0.06, 3), ('pague postos de saude', 0.06, 3), ('postos de saude comunitaria 4', 0.04, 2), ('postos de saude comunitaria 6', 0.04, 2), ('postos de saude comunitaria 7', 0.04, 2), ('postos de saude comunitaria 8', 0.04, 2), ('cantagalo centros de saude', 0.04, 2), ('hospitais', 0.04, 2)]
# ----------------------------------
#
# Country:  Senegal
#
# [('poste de sante', 0.656, 884), ('centre de sante', 0.063, 85), ('hopital regional', 0.01, 13), ('ii poste de sante', 0.007, 10), ('sud poste de sante', 0.006, 8)]
# ----------------------------------
#
# Country:  Seychelles
#
# [('health centre', 0.833, 15), ('praslin health centre', 0.111, 2)]
# ----------------------------------
#
# Country:  Sierra Leone
#
# [('maternal and child health post', 0.467, 523), ('community health post', 0.179, 200), ('community health centre', 0.159, 178), ('health post', 0.021, 24), ('hospital', 0.017, 19), ('government hospital', 0.011, 12), ('health centre', 0.008, 9), ('clinic', 0.006, 7)]
# ----------------------------------
#
# Country:  Somalia
#
# [('health post', 0.471, 414), ('maternal child health centre', 0.301, 265), ('hospital', 0.058, 51), ('health centre', 0.027, 24), ('opd maternal child health centre', 0.02, 18), ('district hospital', 0.011, 10), ('srcs maternal child health centre', 0.007, 6), ('regional hospital', 0.007, 6), ('central maternal child health centre', 0.006, 5), ('weyn health post', 0.006, 5)]
# ----------------------------------
#
# Country:  South Africa
#
# [('clinic', 0.689, 2965), ('hospital', 0.073, 313), ('chc', 0.065, 279), ('satellite clinic', 0.046, 200), ('gateway clinic', 0.029, 125), ('park clinic', 0.008, 35), ('street clinic', 0.008, 34), ('health post', 0.008, 33)]
# ----------------------------------
#
# Country:  South Sudan
#
# [('primary health care unit', 0.695, 1215), ('primary health care centre', 0.168, 294), ('county hospital', 0.016, 28)]
# ----------------------------------
#
# Country:  Sudan
#
# [('hospital', 0.882, 240), ('al', 0.165, 45), ('wadi', 0.04, 11), ('rural hospital', 0.037, 10), ('ad', 0.029, 8), ('abu', 0.022, 6), ('um', 0.022, 6), ('el', 0.018, 5), ('teaching hospital', 0.015, 4), ('town rural hospital', 0.007, 2), ('elshaheid elzubair hospital', 0.007, 2), ('north al', 0.007, 2), ('pediatric hospital', 0.007, 2), ('um durman', 0.007, 2), ('salih hospital', 0.007, 2), ('hospitgal hospital', 0.007, 2), ('suakin hospital', 0.007, 2), ('sennar hospital', 0.007, 2), ('portsudan', 0.007, 2), ('ahmed', 0.007, 2), ('ban', 0.007, 2), ('bahri', 0.007, 2), ('chinese', 0.007, 2), ('m', 0.007, 2), ('un', 0.007, 2), ('en', 0.007, 2), ('elsalam', 0.007, 2), ('jabeit', 0.007, 2), ('jebel', 0.007, 2)]
# ----------------------------------
#
# Country:  Tanzania
# [('dispensary', 0.815, 5138), ('health centre', 0.106, 669), ('hospital', 0.013, 81), ('district hospital', 0.01, 63), ('rc dispensary', 0.008, 50), ('designated district hospital', 0.006, 36), ('mission dispensary', 0.006, 37), ('st', 0.006, 38)]
# ----------------------------------
#
# Country:  Togo
#
# [('unite de soins peripherique', 0.541, 112), ('centre medicosocial', 0.246, 51), ('centre hospitalier prefectoral', 0.145, 30), ('centre hospitalier regional', 0.024, 5), ('tomegbe unite de soins peripherique', 0.01, 2), ('tove unite de soins peripherique', 0.01, 2), ('cope unite de soins peripherique', 0.01, 2), ('university centre hospitalier universitaire', 0.01, 2), ('sokode centre hospitalier', 0.01, 2), ('atakpame centre hospitalier', 0.01, 2)]
# ----------------------------------
#
# Country:  Uganda
#
# [('health centre ii', 0.557, 2114), ('health centre iii', 0.314, 1192), ('health centre iv', 0.05, 188), ('hospital', 0.029, 109)]
# ----------------------------------
#
# Country:  Zambia
#
# [('health post', 0.65, 821), ('rural health centre', 0.085, 107), ('health centre', 0.078, 98), ('clinic clinic', 0.03, 38), ('district level 1 hospital', 0.022, 28), ('mission level 1 hospital', 0.019, 24), ('level 1 hospital', 0.013, 16), ('general level 2 hospital', 0.006, 8), ('urban clinic clinic', 0.006, 8)]
# ----------------------------------
#
# Country:  Zanzibar
#
# [('primary health care unit', 0.862, 125), ('mchangani primary health care unit', 0.028, 4), ('primary health care centre', 0.028, 4), ('ngombe primary health care unit', 0.014, 2), ('ziwani primary health care unit', 0.014, 2), ('charawe primary health care unit', 0.014, 2), ('kidoti primary health care unit', 0.014, 2), ('district hospital', 0.014, 2), ('hospital', 0.014, 2)]
# ----------------------------------
#
# Country:  Zimbabwe
#
# [('clinic', 0.445, 550), ('rural health clinic', 0.4, 495), ('rural hospital', 0.084, 104), ('district hospital', 0.038, 47), ('provincial hospital', 0.006, 7)]
# ----------------------------------

# %%
# Format the results from the common phrases finding process to a DataFrame
result_df = pd.DataFrame(country_and_common_facility_types.items(),columns=['Country','Type'])
result_df = result_df.explode('Type')
result_df[['Type','Proportion within Country','Count']] = pd.DataFrame(result_df['Type'].tolist(), index = result_df.index)
result_df.Country = result_df.Country.apply(str.lower)
result_df.Type = result_df.Type.apply(str.lower)
result_df = result_df.sort_values(['Country','Proportion within Country'], ascending=[True, False]).reset_index(drop=True)

# %%
result_df.head(10)
# Out:
#   Country                             Type  Proportion within Country  Count
# 0  angola                      health post                      0.590    929
# 1  angola                    health centre                      0.121    191
# 2  angola               municipal hospital                      0.047     74
# 3  angola          centro materno infantil                      0.026     41
# 4  angola                         hospital                      0.018     28
# 5  angola            hospital municipal de                      0.014     22
# 6  angola               sede health centre                      0.008     12
# 7   benin  centre de sante darrondissement                      0.366    300
# 8   benin                  centre de sante                      0.295    242
# 9   benin         centre communal de sante                      0.161    132

# %% [markdown]
# ### Computer aided correction

# %%
# From the result above, we can see that common phrases include tokens that might not 
# be description health facility type, but rather places where the facilities are at

# One solution is to check if the first token in the matched type is a place in that country
# or if the token has some speical meaning...

result_df['first_token'] = result_df['Type'].apply(lambda x: x.split()[0])

# To narrow the scope we need to check, first identify some tokens that are obviously part of facility type:
tokens_that_are_part_of_facility_type = ['health', 'centre', 'hospital', 'clinic', 'hopital', 'district', 'postos', 'st', 'community', 'centro', 'primary', 'ii', 'mission', 'rural', 'poste', '2', 'dispensaire', '1', 'dispensary', 'general', 'central', 'hospitais', 'government', 'provincial', 'i', 'basic', 'mini', 'town', 'polyclinique', 'regional', 'clinique', 'hospitalier', 'urbain', 'public', 'de', 'referral', 'new', 'maternal', 'catholique'] # print(result_df['first_token'].value_counts()[result_df['first_token'].value_counts()>1].index.tolist())

# The dataframe below contains the facility types that might not be a valid facility type.
potential_places_as_prefix = result_df[~result_df['first_token'].isin(tokens_that_are_part_of_facility_type)].copy()

# %%
from scraper_functions import *

# %%
# Automate the process of searching these token on Google, record our decision when seeing the search results

def ask_google(list_of_search_keyword, input_guide):
    answers = []
    for search_keyword in list_of_search_keyword:
        go_to_page(driver, 'https://www.google.com/search?q='+search_keyword)
        answers.append(input(input_guide))
        print('\n')
    return answers

list_of_search_keyword = (potential_places_as_prefix['Country'] + '+' + potential_places_as_prefix['first_token']).to_list()

answers = ask_google(list_of_search_keyword, 'Is this a place or place type or facility or unable to tell? (p/t/f/u)')
potential_places_as_prefix['category_of_first_token'] = answers

# %%
# # The recorded answers from previous run:
potential_places_as_prefix['category_of_first_token'] = list('ttfpppfttutuffuptuppupppufpppppuppppuuuutptpppptppppffpufupppppppufftfpfptuffffffuffftfttftftffuppppufpfffpffffppppppppppfpppppppppppfpppptpffpfffuutupupptfuufpuupppuupfuuupppfffppufppufppppp')

# %% [markdown]
# During the Google Search process, take notes of the special abbreviation:
#
# - RCH : Reproductive Child Health
# - GFPA : Gambia Family Planning Association
# - AIC : Africa Inland Church
# - SDA : Seventh Day Adventist
# - PHC : Primary Health Care
# - FOSACOM : Formation Sanitaire Communautaire
# - OPD : Out-Patient Department
# - SRCS : Somali Red Crescent Society
# - CHC : Community Health Center
# - RC : Red Cross
# - ACK : Anglican Church of Kenya
# - UVS : Unites Villageoises de Sante

# %%
# # Inspect the results from our Google Search process
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 'p']
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 't']
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 'f']
# potential_places_as_prefix[potential_places_as_prefix.category_of_first_token == 'u']

# %%
# Map the category we recorded back to the main result dataframe
token_to_category_mapping = potential_places_as_prefix.set_index('first_token')['category_of_first_token'].to_dict()
result_df['category_of_first_token'] = result_df['first_token'].apply(lambda x: token_to_category_mapping.get(x, 'f'))
result_df['category_of_first_token'].value_counts()
# Out:
# f    341
# p     90
# u     33
# t     19
# Name: category_of_first_token, dtype: int64

# %%
# Identify the facility types that are common enough to be considered new facility types
new_facility_types = ['municipal hospital', 'sede health centre', 'vaz postos sanitarios', 'pedro postos sanitarios', 'est centre de sante', 'gare centre de sante integre', 'adi health station', 'sud health centre', 'area health centre', 'sud poste de sante', 'county hospital'] # print(result_df.loc[result_df['category_of_first_token']=='t','Type'].tolist())
result_df.loc[result_df['Type'].isin(new_facility_types), 'category_of_first_token'] = 'f'
result_df.loc[result_df['Type'].apply(lambda x: x.isnumeric()), 'category_of_first_token'] = 'u'
result_df = result_df[~result_df['category_of_first_token'].isin(['p', 't', 'u'])].reset_index(drop=True).drop(['first_token','category_of_first_token'], axis=1)

# %%
result_df.to_csv('../B_semi_data/type_dict_tim.csv',index=False)

# %%
result_df['Country-Type'] = result_df['Country'] + ' - ' +result_df['Type']

# %% [markdown]
# ### Compare extracted types with type_dict_augmented_1130

# %%
type_dict_1130 = pd.read_csv('../github_downloaded_datasets/type_dict_augmented_1130.csv')
type_dict_1130.Country = type_dict_1130.Country.apply(str.lower)
type_dict_1130.Type = type_dict_1130.Type.apply(str.lower)
type_dict_1130 = type_dict_1130.sort_values(['Country','Type']).reset_index(drop=True)
type_dict_1130['Country-Type'] = type_dict_1130['Country'] + ' - ' +type_dict_1130['Type']

# %%
assert(sorted(result_df.Country.unique().tolist()) == sorted(type_dict_1130.Country.unique().tolist()))

# %%
agreed_country_types = result_df[result_df['Country-Type'].isin(type_dict_1130['Country-Type'].tolist())].reset_index(drop=True)

agreed_country_types
# Out:
#       Country                     Type  Proportion within Country  Count  \
# 0      angola       municipal hospital                      0.047     74
# 1      angola  centro materno infantil                      0.026     41
# 2      angola                 hospital                      0.018     28
# 3       benin          centre de sante                      0.295    242
# 4       benin           centre medical                      0.027     22
# ..        ...                      ...                        ...    ...
# 163  zimbabwe                   clinic                      0.445    550
# 164  zimbabwe      rural health clinic                      0.400    495
# 165  zimbabwe           rural hospital                      0.084    104
# 166  zimbabwe        district hospital                      0.038     47
# 167  zimbabwe      provincial hospital                      0.006      7
#
#                          Country-Type
# 0         angola - municipal hospital
# 1    angola - centro materno infantil
# 2                   angola - hospital
# 3             benin - centre de sante
# 4              benin - centre medical
# ..                                ...
# 163                 zimbabwe - clinic
# 164    zimbabwe - rural health clinic
# 165         zimbabwe - rural hospital
# 166      zimbabwe - district hospital
# 167    zimbabwe - provincial hospital
#
# [168 rows x 5 columns]

# %%
unique_to_type_dict_1130 = type_dict_1130[~type_dict_1130['Country-Type'].isin(result_df['Country-Type'].tolist())].reset_index(drop=True)

unique_to_type_dict_1130
# Out:
#       Country                               Type Abbreviation   count  \
# 0      angola                   central hospital           CH     3.0
# 1      angola                    centro de saude           CS   231.0
# 2      angola  centro sanatorio materno infantil         CSMI     3.0
# 3      angola                   general hospital           GH     3.0
# 4      angola                     posto de saude           PS  1152.0
# ..        ...                                ...          ...     ...
# 243    zambia        universty teaching hospital          UTH     NaN
# 244  zanzibar      primary health care unit plus        PHCUP    28.0
# 245  zanzibar                  tertiary hospital           TH     1.0
# 246  zimbabwe                   central hospital           CH     6.0
# 247  zimbabwe       district/provincial hospital          DPH     1.0
#
#                                    Country-Type
# 0                     angola - central hospital
# 1                      angola - centro de saude
# 2    angola - centro sanatorio materno infantil
# 3                     angola - general hospital
# 4                       angola - posto de saude
# ..                                          ...
# 243        zambia - universty teaching hospital
# 244    zanzibar - primary health care unit plus
# 245                zanzibar - tertiary hospital
# 246                 zimbabwe - central hospital
# 247     zimbabwe - district/provincial hospital
#
# [248 rows x 5 columns]

# %%
df[(df.Country=='angola')&(df.lowered_cleaned_name.str.contains('centro de saude'))]
# Out:
# Empty DataFrame
# Columns: [Country, Admin1, name, Type, Ownership, Lat, Long, LL source, coordinates, deaccented_name, special_char_removed_name, lowered_cleaned_name]
# Index: []

# %%
unique_to_result_df = result_df[~result_df['Country-Type'].isin(type_dict_1130['Country-Type'].tolist())].reset_index(drop=True)

unique_to_result_df
# Out:
#       Country                             Type  Proportion within Country  \
# 0      angola                      health post                      0.590
# 1      angola                    health centre                      0.121
# 2      angola            hospital municipal de                      0.014
# 3      angola               sede health centre                      0.008
# 4       benin  centre de sante darrondissement                      0.366
# ..        ...                              ...                        ...
# 176    zambia        district level 1 hospital                      0.022
# 177    zambia         mission level 1 hospital                      0.019
# 178    zambia         general level 2 hospital                      0.006
# 179    zambia              urban clinic clinic                      0.006
# 180  zanzibar                         hospital                      0.014
#
#      Count                             Country-Type
# 0      929                     angola - health post
# 1      191                   angola - health centre
# 2       22           angola - hospital municipal de
# 3       12              angola - sede health centre
# 4      300  benin - centre de sante darrondissement
# ..     ...                                      ...
# 176     28       zambia - district level 1 hospital
# 177     24        zambia - mission level 1 hospital
# 178      8        zambia - general level 2 hospital
# 179      8             zambia - urban clinic clinic
# 180      2                      zanzibar - hospital
#
# [181 rows x 5 columns]

# %% [markdown]
# ### Compare extracted types with the types that comes with nature dataset

# %%
country_to_facility_types_mapping = result_df.groupby('Country').agg({'Type':list}).to_dict()['Type']

# %%
def get_matched_type_and_pure_name(country_name, name):

    facility_types = country_to_facility_types_mapping[country_name]

    facility_types = sorted(facility_types, key = lambda x: -len(x.split()))

    matched_type = np.nan
    for facility_type in facility_types:
        if ' '+facility_type+' ' in ' '+name+' ':
            matched_type = facility_type
            break

    if isinstance(matched_type,str):
        pure_name = name.replace(matched_type,'').strip()
    else:
        pure_name = np.nan
        
    return (matched_type,pure_name)

# %%
df['Type'] = df['Type'].apply(str.lower).apply(deaccent)

df[['matched_type','pure_name']] = pd.DataFrame(df[['Country','lowered_cleaned_name']].apply(lambda row: get_matched_type_and_pure_name(row['Country'].lower(), row['lowered_cleaned_name']), axis=1).tolist(), index= df.index)

# %%
print('\n'+str(np.round(df.matched_type.notnull().mean()*100,2))+'% of the nature dataset is covered by the extracted types.')

print('\nFor '+str(np.round(sum(df.Type==df.matched_type)/len(df)*100,2))+'% of the nature dataset, provided type and extracted type are exactly the same.')

different_type = df.loc[(df.Type!=df.matched_type) & df.Type.notnull() & df.matched_type.notnull(), ['Country','name','Type','matched_type']]

print('\nFor '+str(np.round(len(different_type)/len(df)*100,2))+'% of the nature dataset, the provided type and extracted type are different. Below are some examples:\n')

different_type.drop_duplicates(subset=['Type','matched_type']).rename(columns={'Type':'original_type'})[:20]
# Out:
# 98.57% of the nature dataset is covered by the extracted types.
#
# For 84.09% of the nature dataset, provided type and extracted type are exactly the same.
#
# For 14.48% of the nature dataset, the provided type and extracted type are different. Below are some examples:
#            Country                                                 name  \
# 2           Angola                         Hospital Municipal de Ambriz
# 8           Angola                         Hospital Provincial de Bengo
# 9           Angola                              27 de Marto Health Post
# 10          Angola                  Abrigo Anjo da Guarda Health Centre
# 29          Angola                 Bela Vistal  Centro Materno Infantil
# 35          Angola                             Benguela/Lobito Hospital
# 105         Angola                       Dombe Grande Communal Hospital
# 366         Angola                        Boa Entrada Regional Hospital
# 447         Angola                        Hospital Geral 17 de Setembro
# 526         Angola                                   Sede Health Centre
# 1575         Benin                            Alfakoara Centre de santé
# 1576         Benin                 Angaradebou Centre Communal de Santé
# 1583         Benin            Bensekou Centre de Santé d’Arrondissement
# 1597         Benin          Gogounou Centre de Santé de Sous-Prefecture
# 1641         Benin              Tissarou UVS Unites de Santé de Village
# 2411      Botswana                                 Dimajwe  Health Post
# 3881  Burkina Faso  Csps Urbain Centre de Santé Et de Promotion Sociale
# 4740       Burundi                            Bubanza I Centre de Santé
# 4889       Burundi                           Muzenga Ii Centre de Santé
# 5407      Cameroon                      Atta Catholique Centre de Santé
#
#                                 original_type  \
# 2                          municipal hospital
# 8                         provincial hospital
# 9                              posto de saude
# 10                            centro de saude
# 29                            centro de saude
# 35                           central hospital
# 105                        municipal hospital
# 366                         regional hospital
# 447                          general hospital
# 526                           centro de saude
# 1575                            health centre
# 1576                  community health centre
# 1583         centre de sante d'arrondissement
# 1597       centre de sante de sous-prefecture
# 1641               unites de sante de village
# 2411                                   clinic
# 3881  centre de sante et de promotion sociale
# 4740                            health centre
# 4889                            health centre
# 5407                            health centre
#
#                                         matched_type
# 2                              hospital municipal de
# 8                                           hospital
# 9                                        health post
# 10                                     health centre
# 29                           centro materno infantil
# 35                                          hospital
# 105                                         hospital
# 366                                         hospital
# 447                                         hospital
# 526                               sede health centre
# 1575                                 centre de sante
# 1576                        centre communal de sante
# 1583                 centre de sante darrondissement
# 1597               centre de sante de sousprefecture
# 1641                  uvs unites de sante de village
# 2411                                     health post
# 3881  urbain centre de sante et de promotion sociale
# 4740                               i centre de sante
# 4889                              ii centre de sante
# 5407                      catholique centre de sante
